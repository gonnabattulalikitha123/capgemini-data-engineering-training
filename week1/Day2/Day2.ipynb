-- %%
CREATE TABLE Employee (
emp_id INT PRIMARY KEY,
emp_name VARCHAR(50),
department VARCHAR(50),
salary DECIMAL(10, 2),
joining_date DATE
);
-- Out:
-- ---------------------------------------------------------------------------
-- AnalysisException                         Traceback (most recent call last)
-- File <command-4641420547964704>, line 1
-- ----> 1 get_ipython().run_cell_magic('sql', '', 'CREATE TABLE Employee (\nemp_id INT PRIMARY KEY,\nemp_name VARCHAR(50),\ndepartment VARCHAR(50),\nsalary DECIMAL(10, 2),\njoining_date DATE\n);\n')
--
-- File /databricks/python/lib/python3.12/site-packages/IPython/core/interactiveshell.py:2541, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
--    2539 with self.builtin_trap:
--    2540     args = (magic_arg_s, cell)
-- -> 2541     result = fn(*args, **kwargs)
--    2543 # The code below prevents the output from being displayed
--    2544 # when using magics with decorator @output_can_be_silenced
--    2545 # when the last Python token in the expression is a ';'.
--    2546 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
--
-- ...

-- %%
INSERT INTO Employee (emp_id, emp_name, department, salary, joining_date) VALUES
(1, 'Karthik', 'HR', 60000.00, '2021-01-15'),
(2, 'Pratik', 'Finance', 70000.00, '2021-03-10'),
(3, 'Veer', 'HR', 55000.00, '2021-06-20'),
(4, 'Priya', 'Finance', 80000.00, '2022-01-05'),
(5, 'Ajay', 'Engineering', 75000.00, '2020-11-01'),
(6, 'Vijay', 'Engineering', 78000.00, '2019-05-22'),
(7, 'Veena', 'HR', 62000.00, '2023-03-12'),
(8, 'Meena', 'Marketing', 65000.00, '2022-08-18');

-- %%
CREATE TABLE Sales (
sales_id INT PRIMARY KEY,
emp_id INT,
product VARCHAR(50),
amount DECIMAL(10, 2),
sale_date DATE
);

-- %%
INSERT INTO Sales (sales_id, emp_id, product, amount, sale_date) VALUES
(1, 1, 'Laptop', 50000.00, '2023-01-15'),
(2, 2, 'Mobile', 30000.00, '2023-02-18'),
(3, 3, 'Tablet', 20000.00, '2023-02-25'),
(4, 4, 'Laptop', 45000.00, '2023-03-05'),
(5, 5, 'Mobile', 35000.00, '2023-03-12'),
(6, 6, 'Tablet', 25000.00, '2023-03-20'),
(7, 7, 'Laptop', 60000.00, '2023-04-01'),
(8, 8, 'Mobile', 40000.00, '2023-04-10');

-- %%
SELECT department,sum(salary) AS total_salary from Employee group by department;
SELECT department,count(emp_id) from Employee group by department;

SELECT department, avg(salary) FROM Employee  group by department;

SELECT department,max(salary) FROM Employee group by department;

SELECT department,min(salary) FROM Employee group by department;

SELECT department,sum(salary) FROM Employee group by department having sum(salary)>100000;


SELECT department,count(emp_id) FROM Employee group by department having count(emp_id)>2;


SELECT department,avg(salary) FROM Employee  where joining_date>'2021-01-01' group by department;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>department</th><th>avg(salary)</th></tr></thead><tbody><tr><td>HR</td><td>59000.000000</td></tr><tr><td>Finance</td><td>75000.000000</td></tr><tr><td>Marketing</td><td>65000.000000</td></tr></tbody></table></div>

-- %%
SELECT department,sum(salary) AS total_salary from Employee group by department;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>department</th><th>total_salary</th></tr></thead><tbody><tr><td>HR</td><td>177000.00</td></tr><tr><td>Finance</td><td>150000.00</td></tr><tr><td>Engineering</td><td>153000.00</td></tr><tr><td>Marketing</td><td>65000.00</td></tr></tbody></table></div>

-- %%
SELECT department,count(emp_id) from Employee group by department;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>department</th><th>count(emp_id)</th></tr></thead><tbody><tr><td>HR</td><td>3</td></tr><tr><td>Finance</td><td>2</td></tr><tr><td>Engineering</td><td>2</td></tr><tr><td>Marketing</td><td>1</td></tr></tbody></table></div>

-- %%
SELECT department, avg(salary) FROM Employee  group by department;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>department</th><th>avg(salary)</th></tr></thead><tbody><tr><td>HR</td><td>59000.000000</td></tr><tr><td>Finance</td><td>75000.000000</td></tr><tr><td>Engineering</td><td>76500.000000</td></tr><tr><td>Marketing</td><td>65000.000000</td></tr></tbody></table></div>

-- %%
SELECT department,max(salary) FROM Employee group by department;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>department</th><th>max(salary)</th></tr></thead><tbody><tr><td>HR</td><td>62000.00</td></tr><tr><td>Finance</td><td>80000.00</td></tr><tr><td>Engineering</td><td>78000.00</td></tr><tr><td>Marketing</td><td>65000.00</td></tr></tbody></table></div>

-- %%
SELECT department,min(salary) FROM Employee group by department;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>department</th><th>min(salary)</th></tr></thead><tbody><tr><td>HR</td><td>55000.00</td></tr><tr><td>Finance</td><td>70000.00</td></tr><tr><td>Engineering</td><td>75000.00</td></tr><tr><td>Marketing</td><td>65000.00</td></tr></tbody></table></div>

-- %%
SELECT department,sum(salary) FROM Employee group by department having sum(salary)>100000;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>department</th><th>sum(salary)</th></tr></thead><tbody><tr><td>HR</td><td>177000.00</td></tr><tr><td>Finance</td><td>150000.00</td></tr><tr><td>Engineering</td><td>153000.00</td></tr></tbody></table></div>

-- %%
SELECT department,count(emp_id) FROM Employee group by department having count(emp_id)>2;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>department</th><th>count(emp_id)</th></tr></thead><tbody><tr><td>HR</td><td>3</td></tr></tbody></table></div>

-- %%
SELECT department,avg(salary) FROM Employee  where joining_date>'2021-01-01' group by department;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>department</th><th>avg(salary)</th></tr></thead><tbody><tr><td>HR</td><td>59000.000000</td></tr><tr><td>Finance</td><td>75000.000000</td></tr><tr><td>Marketing</td><td>65000.000000</td></tr></tbody></table></div>

-- %%
SELECT department,max(salary) from Employee group by department having max(salary)>75000;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>department</th><th>max(salary)</th></tr></thead><tbody><tr><td>Finance</td><td>80000.00</td></tr><tr><td>Engineering</td><td>78000.00</td></tr></tbody></table></div>

-- %%
SELECT department,sum(salary) from Employee group by department having sum(salary)>150000;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>department</th><th>sum(salary)</th></tr></thead><tbody><tr><td>HR</td><td>177000.00</td></tr><tr><td>Engineering</td><td>153000.00</td></tr></tbody></table></div>

-- %%
SELECT department,count(emp_id) FROM Employee group by department having count(emp_id)>1;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>department</th><th>count(emp_id)</th></tr></thead><tbody><tr><td>HR</td><td>3</td></tr><tr><td>Finance</td><td>2</td></tr><tr><td>Engineering</td><td>2</td></tr></tbody></table></div>

-- %%
SELECT department,sum(salary) FROM Employee group by department having sum(salary)>125000;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>department</th><th>sum(salary)</th></tr></thead><tbody><tr><td>HR</td><td>177000.00</td></tr><tr><td>Finance</td><td>150000.00</td></tr><tr><td>Engineering</td><td>153000.00</td></tr></tbody></table></div>

-- %%
SELECT department,count(emp_id) FROM Employee group by department having count(emp_id)>1;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>department</th><th>count(emp_id)</th></tr></thead><tbody><tr><td>HR</td><td>3</td></tr><tr><td>Finance</td><td>2</td></tr><tr><td>Engineering</td><td>2</td></tr></tbody></table></div>

-- %%
SELECT department,count(emp_id) FROM Employee group by department having count(emp_id)>2;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>department</th><th>count(emp_id)</th></tr></thead><tbody><tr><td>HR</td><td>3</td></tr></tbody></table></div>

-- %%
SELECT department,avg(salary) FROM Employee group by department having avg(salary)>60000;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>department</th><th>avg(salary)</th></tr></thead><tbody><tr><td>Finance</td><td>75000.000000</td></tr><tr><td>Engineering</td><td>76500.000000</td></tr><tr><td>Marketing</td><td>65000.000000</td></tr></tbody></table></div>

-- %%
SELECT department,sum(salary) from Employee group by department having sum(salary) BETWEEN 100000 AND 200000;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>department</th><th>sum(salary)</th></tr></thead><tbody><tr><td>HR</td><td>177000.00</td></tr><tr><td>Finance</td><td>150000.00</td></tr><tr><td>Engineering</td><td>153000.00</td></tr></tbody></table></div>

-- %%
CREATE TABLE employees (
emp_id INT PRIMARY KEY,
emp_name VARCHAR(50),
manager_id INT,
dept_id INT
);

-- %%
INSERT INTO employees (emp_id, emp_name, manager_id, dept_id) VALUES
(1, 'Karthik', NULL, 1),
(2, 'Ajay', 1, 1),
(3, 'Vijay', 1, 2),
(4, 'Vinay', 2, 2),
(5, 'Meena', 3, 3),
(6, 'Veer', NULL, 4),
(7, 'Keerthi', 4, 5),
(8, 'Priya', 4, 5);
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>8</td><td>8</td></tr></tbody></table></div>

-- %%
select e.emp_name AS employee_name, m.manager_id AS manager_name FROM employees e  JOIN employees m ON e.emp_id =m.emp_id;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>employee_name</th><th>manager_name</th></tr></thead><tbody><tr><td>Karthik</td><td>null</td></tr><tr><td>Ajay</td><td>1</td></tr><tr><td>Vijay</td><td>1</td></tr><tr><td>Vinay</td><td>2</td></tr><tr><td>Meena</td><td>3</td></tr><tr><td>Veer</td><td>null</td></tr><tr><td>Keerthi</td><td>4</td></tr><tr><td>Priya</td><td>4</td></tr></tbody></table></div>

-- %%
CREATE TABLE departments (
dept_id INT PRIMARY KEY,
dept_name VARCHAR(50)
);

-- %%
INSERT INTO departments (dept_id, dept_name) VALUES
(1, 'HR'),
(2, 'IT'),
(3, 'Finance'),
(4, 'Marketing'),
(5, 'Sales');
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>5</td><td>5</td></tr></tbody></table></div>

-- %%
select e.emp_name,d.dept_name from employees e left join departments d on e.dept_id=d.dept_id;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_name</th><th>dept_name</th></tr></thead><tbody><tr><td>Karthik</td><td>HR</td></tr><tr><td>Ajay</td><td>HR</td></tr><tr><td>Vijay</td><td>IT</td></tr><tr><td>Vinay</td><td>IT</td></tr><tr><td>Meena</td><td>Finance</td></tr><tr><td>Veer</td><td>Marketing</td></tr><tr><td>Keerthi</td><td>Sales</td></tr><tr><td>Priya</td><td>Sales</td></tr></tbody></table></div>

-- %%
select e.emp_name AS employee_name, m.manager_id AS manager_name FROM employees e  JOIN employees m ON e.manager_id =m.manager_id;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>employee_name</th><th>manager_name</th></tr></thead><tbody><tr><td>Ajay</td><td>1</td></tr><tr><td>Vijay</td><td>1</td></tr><tr><td>Vinay</td><td>2</td></tr><tr><td>Meena</td><td>3</td></tr><tr><td>Keerthi</td><td>4</td></tr><tr><td>Priya</td><td>4</td></tr><tr><td>Ajay</td><td>1</td></tr><tr><td>Vijay</td><td>1</td></tr><tr><td>Keerthi</td><td>4</td></tr><tr><td>Priya</td><td>4</td></tr></tbody></table></div>

-- %%
--18

SELECT e.emp_name,d.dept_name from employees e left join departments d on e.dept_id=d.dept_id;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_name</th><th>dept_name</th></tr></thead><tbody><tr><td>Karthik</td><td>HR</td></tr><tr><td>Ajay</td><td>HR</td></tr><tr><td>Vijay</td><td>IT</td></tr><tr><td>Vinay</td><td>IT</td></tr><tr><td>Meena</td><td>Finance</td></tr><tr><td>Veer</td><td>Marketing</td></tr><tr><td>Keerthi</td><td>Sales</td></tr><tr><td>Priya</td><td>Sales</td></tr></tbody></table></div>

-- %%
--19
SELECT e.emp_name,d.dept_name,count(d.dept_id) as c from employees e  join departments d on e.dept_id=d.dept_id group by e.emp_name,d.dept_name having count(d.dept_id)>1;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_name</th><th>dept_name</th><th>c</th></tr></thead><tbody></tbody></table></div>

-- %%
--20
select d.dept_name,e.emp_name from departments d left join employees e on d.dept_id=e.dept_id;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>dept_name</th><th>emp_name</th></tr></thead><tbody><tr><td>HR</td><td>Ajay</td></tr><tr><td>IT</td><td>Vinay</td></tr><tr><td>Finance</td><td>Meena</td></tr><tr><td>Marketing</td><td>Veer</td></tr><tr><td>Sales</td><td>Priya</td></tr><tr><td>HR</td><td>Karthik</td></tr><tr><td>IT</td><td>Vijay</td></tr><tr><td>Sales</td><td>Keerthi</td></tr></tbody></table></div>

-- %%
CREATE TABLE projects (
project_id INT PRIMARY KEY,
project_name VARCHAR(50),
emp_id INT
);

-- %%
INSERT INTO projects (project_id, project_name, emp_id) VALUES
(1, 'Project A', 1),
(2, 'Project B', 2),
(3, 'Project C', 3),
(4, 'Project D', 4),
(5, 'Project E', 5);
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>5</td><td>5</td></tr></tbody></table></div>

-- %%
--21
SELECT e.emp_name,p.project_name from employees e  left join projects p on e.emp_id=p.emp_id where e.dept_id is null and p.project_id is not null
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_name</th><th>project_name</th></tr></thead><tbody></tbody></table></div>

-- %%
--22
select d.dept_name,count(e.emp_id) as number_of_emp from employees e right join departments d on e.dept_id=d.dept_id group by d.dept_name;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>dept_name</th><th>number_of_emp</th></tr></thead><tbody><tr><td>Sales</td><td>2</td></tr><tr><td>IT</td><td>2</td></tr><tr><td>HR</td><td>2</td></tr><tr><td>Finance</td><td>1</td></tr><tr><td>Marketing</td><td>1</td></tr></tbody></table></div>
