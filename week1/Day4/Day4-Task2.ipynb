-- %%
CREATE TABLE pyspark_survey7 (
    timestamp STRING,
    email_address VARCHAR(255), 
    completed_all_5_queries STRING,
    github_username VARCHAR (255),
    repository_link STRING,
    phase1_folder_link STRING
)
USING DELTA;

-- %%
INSERT INTO pyspark_survey7 VALUES
('3/28/2026 16:28', '22pa1a42a9@vishnu.edu.in', 'Yes', 'Poorna-135', 'https://github.com/Poorna-135/Capgemini-DataEngineering-training/tree/main', 'https://github.com/Poorna-135/Capgemini-DataEngineering-training/tree/main/Week0/Phase1'),
('3/28/2026 12:06', '22pa1a4279@vishnu.edu.in', 'No', 'Nallamellisubhash', 'https://github.com/Nallamellisubhash/PYSPARK_PRACTICE', 'https://github.com/Nallamellisubhash/PYSPARK_PRACTICE/tree/main'),
('3/28/2026 22:02', '22pa1a12e7@vishnu.edu.in', 'Yes', 'deepu-04', 'https://github.com/deepu-04/capgemini-data-engineering-training', 'https://github.com/deepu-04/capgemini-data-engineering-training/tree/main/week0'),
('3/28/2026 12:55', '22pa1a0554@vishnu.edu.in', 'Yes', 'deepikagundu2622', 'https://github.com/deepikagundu2622/capgemini-data-engineering-training.git', 'https://github.com/deepikagundu2622/capgemini-data-engineering-training/tree/main/phase1'),
('3/28/2026 14:55', '22pa1a1293@vishnu.edu.in', 'Yes', 'Manasa-Codes', 'https://github.com/Manasa-Codes/capgemini-data-engineering-training', 'https://github.com/Manasa-Codes/capgemini-data-engineering-training/tree/main/week0/phase1'),
('3/28/2026 14:59', '22pa1a4505@vishnu.edu.in', 'Yes', 'Johnpaul-225', 'https://github.com/Johnpaul-225/capgemini-data-engineering-training.git', 'https://github.com/Johnpaul-225/capgemini-data-engineering-training/tree/main/databricks-week0-foundation/phase1'),
('3/28/2026 15:28', '23pa5a4506@vishnu.edu.in', 'Yes', 'praveenapagadala', 'https://github.com/praveenapagadala/capgemini-databricks-data-engineering/', 'https://github.com/praveenapagadala/capgemini-databricks-data-engineering/tree/main/week0/phase1'),
('3/28/2026 18:16', '22pa1a1275@vishnu.edu.in', 'Yes', 'Siddhardha2330', 'https://github.com/Siddhardha2330/capgemini-data-engineering-training', 'https://github.com/Siddhardha2330/capgemini-data-engineering-training/tree/main/week0/phase1'),
('3/28/2026 17:27', '22pa1a0596@vishnu.edu.in', 'Yes', 'Mamilla-Praveen', 'https://github.com/Mamilla-Praveen/Capgemini-data-engineering-training', 'https://github.com/Mamilla-Praveen/Capgemini-data-engineering-training/tree/main/phase1'),
('3/28/2026 15:47', '22pa1a0551@vishnu.edu.in', 'Yes', 'jyothisreevinaya', 'https://github.com/jyothisreevinaya/capgemini-data-engineering-training.git', 'https://github.com/jyothisreevinaya/capgemini-data-engineering-training/tree/main/week0/phase1'),
('3/28/2026 16:11', '22pa1a12j3@vishnu.edu.in', 'No', 'SriBhargav999', 'https://github.com/SriBhargav999/capgemini-data-enginering-training', 'https://github.com/SriBhargav999/capgemini-data-enginering-training/tree/a138690a2faef9ff45889ce648788bd37a030141/week_0/Phase_1'),
('3/28/2026 18:10', '22pa1a05c0@vishnu.edu.in', 'Yes', 'bhavyasri9', 'https://github.com/bhavyasri9/capgemini-data-engineering-training', 'https://github.com/bhavyasri9/capgemini-data-engineering-training/tree/main/week0/phase1'),
('3/28/2026
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>51</td><td>51</td></tr></tbody></table></div>

-- %%
CREATE TABLE students1 (
    superset_id        STRING,
    regno              VARCHAR(20),
    student_name       STRING,
    gender             STRING,
    branch             STRING,
    tenth_percentage   DECIMAL(5,2),
    inter_percentage   DECIMAL(5,2),
    btech_cgpa         DECIMAL(4,2),
    backlogs           INT,
    mobile             STRING,
    college_email      VARCHAR(100),
    personal_email     VARCHAR(100)
)

-- %%
INSERT INTO students1 VALUES
('6131814','22PA1A4505','ALLADI JOHNPAUL','Male','Artificial Intelligence and Data Science',90.66,96.9,9.01,0,'7672048086','22pa1a4505@vishnu.edu.in','johnalladi0306@gmail.com'),
('6131815','22PA1A4506','ALPESH JAIN','Male','Artificial Intelligence and Data Science',98.5,95.7,9.11,0,'7842624644','22pa1a4506@vishnu.edu.in','alpeshjain3112@gmail.com'),
('6131882','22PA1A4573','MUNAGALA SAI MANIKANTA YASHWANTH','Male','Artificial Intelligence and Data Science',97,96.2,8.9,0,'7095237925','22pa1a4573@vishnu.edu.in','myaswanth18@gmail.com'),
('6131889','22PA1A4580','NANNABATTUNI HARSHAVARDHAN CHARI','Male','Artificial Intelligence and Data Science',97,87.4,8.41,0,'8688004565','22pa1a4580@vishnu.edu.in','harshavardhanchari0304@gmail.com'),
('6131890','22PA1A4582','NARRA LAKSHMI HANUMA','Male','Artificial Intelligence and Data Science',92.8,96.4,8.5,0,'7799542164','22pa1a4582@vishnu.edu.in','lakshmihanumanarra816@gmail.com'),
('6131909','22PA1A45A1','SANNIDHI NAGA SRI CHAITANYA','Male','Artificial Intelligence and Data Science',97,96.1,8.92,0,'9542636841','22pa1a45a1@vishnu.edu.in','chaitanyasannidhi8@gmail.com'),
('6131917','22PA1A45A9','THATHA BHAGAVATHI VYSHNAVI','Female','Artificial Intelligence and Data Science',97,96,8.55,0,'9014550394','22pa1a45a9@vishnu.edu.in','thathabhagavathivyshnavi12@gmail.com'),
('6131931','22PA1A45C3','YARLAGADDA SRAVANI','Female','Artificial Intelligence and Data Science',97,89,8.55,0,'6305674617','22pa1a45c3@vishnu.edu.in','yarlagaddasravani991@gmail.com'),
('6131938','23PA5A4506','PAGADALA PRAVEENA RAJESWARI DEVI','Female','Artificial Intelligence and Data Science',98,84.5,8.74,0,'9182854989','23pa5a4506@vishnu.edu.in','pagadalapraveena2004@gmail.com'),
('6132024','22PA1A4279','NALLAMELLI SUBHASH','Male','Artificial Intelligence and Machine Learning',97,95.4,9.09,0,'9032208078','22pa1a4279@vishnu.edu.in','pandunallamelli@gmail.com'),
('6131986','22PA1A4241','GONNABATTULA LIKHITHA','Female','Artificial Intelligence and Machine Learning',99.34,96,9.01,0,'8185990208','22pa1a4241@vishnu.edu.in','likithagonnabattula@gmail.com'),
('6132054','22PA1A42A9','VANGAPANDU POORNA LAKSHMI','Female','Artificial Intelligence and Machine Learning',99.17,86,8.61,0,'9381725008','22pa1a42a9@vishnu.edu.in','poornalakshmi135@gmail.com'),
('6132057','22PA1A42B2','VELLANKI MANASWINI','Female','Artificial Intelligence and Machine Learning',97,60.9,8.23,0,'8328069119','22pa1a42b2@vishnu.edu.in','manuvellanki@gmail.com'),
('6132435','22PA1A1275','KAVURU DEVAKEENANDA SATYA SAI SIDDARDHA','Male','Information Technology',95,92.1,8.29,0,'9440326886','22pa1a1275@vishnu.edu.in','rajasekharkavuru@gmail.com'),
('6132444','22PA1A1283','KORADA SOWMYA','Female','Information Technology',98.99,86,8.24,0,'8317544669','22pa1a1283@vishnu.edu.in','bharathirajukorada59@gmail.com'),
('6132446','22PA1A1285','KOTA SAI ROHITH','Male','Information Technology',95,91,8.47,0,'7075311017','22pa1a1285@vishnu.edu.in','rohithkata438@gmail.com'),
('6132454','22PA1A1293','MALINENI MANASA','Female','Information Technology',95,98.3,8.69,0,'7396794595','22pa1a1293@vishnu.edu.in','manasamalineni@gmail.com'),
('6132506','22PA1A12E7','PRATHIPATI DEEPTHISRI','Female','Information Technology',95,96.1,8.86,0,'7780627752','22pa1a12e7@vishnu.edu.in','deepthisri.prathipati@gmail.com'),
('6132516','22PA1A12F7','SADHU VIVEK','Male','Information Technology',95,98,9.32,0,'8297310979','22pa1a12f7@vishnu.edu.in','viveksadhu369@gmail.com'),
('6132519','22PA1A12G0','SEEDARAPU SANTOSH KUMAR','Male','Information Technology',96,95.7,8.53,0,'7981121106','22pa1a12g0@vishnu.edu.in','seedarapusantosh15@gmail.com'),
('6132531','22PA1A12H3','TANGELLA ROHITH LAKSHMAN KUMAR','Male','Information Technology',95,92.7,8.31,0,'9515551063','22pa1a12h3@vishnu.edu.in','tangellanagararaju48@gmail.com'),
('6132532','22PA1A12H4','TEEGIREDDY KAVYA SREE','Female','Information Technology',85,88.5,8.72,0,'7981573933','22pa1a12h4@vishnu.edu.in','nishika1922@gmail.com'),
('6132551','22PA1A12J3','YERRIBOINA SRI BHARGAV','Male','Information Technology',95,95.3,8.7,0,'7799842709','22pa1a12j3@vishnu.edu.in','sribhargav0401@gmail.com'),
('6132552','22PA1A12J4','ZAKIYA TAHSEEN','Female','Information Technology',96.83,88.4,8.88,0,'6305295002','22pa1a12j4@vishnu.edu.in','zakirhussain.akv@gmail.com'),
('6132554','23PA5A1202','BONTHU DEEPAK','Male','Information Technology',74.98,74.98,7.99,0,'7989214075','23pa5a1202@vishnu.edu.in','bonthudeepak3@gmail.com'),
('6132560','23PA5A1209','KANDIKATLA VIKRAM RAJU','Male','Information Technology',76.71,76.71,8.33,0,'6309067889','23pa5a1209@vishnu.edu.in','vikramrajuvikky006@gmail.com');
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>57</td><td>57</td></tr></tbody></table></div>

-- %%
CREATE TABLE task_responses (
    timestamp STRING,
    email_address STRING,
    completed_all_5_queries BOOLEAN,
    github_username STRING,
    repository_link STRING,
    phase1_folder_link STRING
)

-- %%
INSERT INTO task_responses VALUES
('3/28/2026 16:28', '22pa1a42a9@vishnu.edu.in', 'Yes', 'Poorna-135', 'https://github.com/Poorna-135/Capgemini-DataEngineering-training/tree/main', 'https://github.com/Poorna-135/Capgemini-DataEngineering-training/tree/main/Week0/Phase1'),
('3/28/2026 12:06', '22pa1a4279@vishnu.edu.in', 'No', 'Nallamellisubhash', 'https://github.com/Nallamellisubhash/PYSPARK_PRACTICE', 'https://github.com/Nallamellisubhash/PYSPARK_PRACTICE/tree/main'),
capgemini-data-engineering-training/tree/main/week0/phase1'),
('3/30/2026 1:25', '22pa1a4506@vishnu.edu.in', 'Yes', 'https://github.com/alpzj', 'https://github.com/alpzj/capgemini-data-engineering-training', 'https://github.com/alpzj/capgemini-data-engineering-training/tree/main/Phase1'),
('3/30/2026 10:03', '22pa1a4580@vishnu.edu.in', 'No', 'HARSHA4580', 'https://github.com/HARSHA4580/Capgemini-data-engineering', 'https://github.com/HARSHA4580/Capgemini-data-engineering/tree/main/phase%201'),
('3/30/2026 10:44', '23pa5a1202@vishnu.edu.in', 'Yes', 'deepakbonthu', 'https://github.com/deepakbonthu/capgemini-data-engineering-training/tree/main', 'https://github.com/deepakbonthu/capgemini-data-engineering-training/tree/main/week0%2Fphase1'),
('3/30/2026 11:52', '22pa1a12f7@vishnu.edu.in', 'Yes', 'viveksadhucodes', 'https://github.com/viveksadhucodes/capgemini-data-engineering-training/tree/main', 'https://github.com/viveksadhucodes/capgemini-data-engineering-training/tree/main/databricks-week0-foundation/phase1'),
('3/30/2026 11:53', '22pa1a1240@vishnu.edu.in', 'Yes', 'Amar-1240', 'https://github.com/Amar-1240/capgemini-data-engineering-training/tree/main/week0', 'https://github.com/Amar-1240/capgemini-data-engineering-training/tree/main/week0/phase1'),
('3/30/2026 12:30', '22pa1a5713@vishnu.edu.in', 'Yes', 'Farhana1103', 'https://github.com/Farhana1103/databricks-week0-foundation--', 'https://github.com/Farhana1103/databricks-week0-foundation--/tree/main/phase1'),
('3/30/2026 15:24', '22pa1a1246@vishnu.edu.in', 'Yes', 'balabhargavi12', 'https://github.com/balabhargavi12/capgemini-data-engineering-training/tree/main', 'https://github.com/balabhargavi12/capgemini-data-engineering-training/tree/main/week0/phase1'),
('3/30/2026 16:31', '23pa5a1209@vishnu.edu.in', 'Yes', 'Vikky660', 'https://github.com/Vikky660/Capgemini-data-engineering-training/tree/main', 'https://github.com/Vikky660/Capgemini-data-engineering-training/tree/main/week0/phase1'),
('3/30/2026 17:05', '22pa1a1265@vishnu.edu.in', 'Yes', 'GAYATHRI7171', 'https://github.com/GAYATHRI7171/Capgemini-data-engineering-training/tree/main', 'https://github.com/GAYATHRI7171/Capgemini-data-engineering-training/tree/main/Week0/Phase1'),
('3/30/2026 17:07', '22pa1a4582@vishnu.edu.in', 'Yes', 'Hanumanarra', 'https://github.com/Hanumanarra/data-engineering-training', 'https://github.com/Hanumanarra/data-engineering-training/tree/main/week0/phase1');
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>51</td><td>51</td></tr></tbody></table></div>

-- %%
SELECT *
FROM students1 t1
JOIN task_responses t2
ON t1.college_email = t2.email_address
ORDER BY t2.`Timestamp` ASC
LIMIT 10;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>superset_id</th><th>regno</th><th>student_name</th><th>gender</th><th>branch</th><th>tenth_percentage</th><th>inter_percentage</th><th>btech_cgpa</th><th>backlogs</th><th>mobile</th><th>college_email</th><th>personal_email</th><th>timestamp</th><th>email_address</th><th>completed_all_5_queries</th><th>github_username</th><th>repository_link</th><th>phase1_folder_link</th></tr></thead><tbody><tr><td>6132024</td><td>22PA1A4279</td><td>NALLAMELLI SUBHASH</td><td>Male</td><td>Artificial Intelligence and Machine Learning</td><td>97.00</td><td>95.40</td><td>9.09</td><td>0</td><td>9032208078</td><td>22pa1a4279@vishnu.edu.in</td><td>pandunallamelli@g
.git</td><td>https://github.com/jyothisreevinaya/capgemini-data-engineering-training/tree/main/week0/phase1</td></tr><tr><td>6132551</td><td>22PA1A12J3</td><td>YERRIBOINA SRI BHARGAV</td><td>Male</td><td>Information Technology</td><td>95.00</td><td>95.30</td><td>8.70</td><td>0</td><td>7799842709</td><td>22pa1a12j3@vishnu.edu.in</td><td>sribhargav0401@g ...

-- %%
CREATE TABLE student_submissions4 (
    timestamp VARCHAR(50),
    email VARCHAR(100),
    pyspark_methods varchar(255),
    completed_queries VARCHAR(100),
    github_username VARCHAR(100),
    repository_link  varchar(100),
    phase1_folder_link varchar(100)
);

-- %%
INSERT INTO student_submissions4
(timestamp, email, pyspark_methods, completed_queries, github_username, repository_link, phase1_folder_link)
VALUES
('05-04-2026 18:44', '22pa1a42a9@vishnu.edu.in', 'show,groupby,count,select,filter', 'Yes', 'Poorna-135', 'https://github.com/Poorna-135/Capgemini-DataEngineering-training/tree/main', 'https://github.com/Poorna-135/capgemini-data-engineering-training/tree/main/week%200/phase1'),
('05-04-2026 18:00', '22pa1a4279@vishnu.edu.in', 'i learn how to setup the pyspark ,  creating sparksession, creating a dataframe, and apply some filters on the table like filter,count,show,groupby and select .', 'Yes', 'Nallamellisubhash', 'https://github.com/Nallamellisubhash/capgemini-data-engineering-training', 'https://github.com/Nallamellisubhash/capgemini-data-engineering-training/tree/main/Week0/phase1'),
('28-03-2026 22:02', '22pa1a12e7@vishnu.edu.in', 'filter() , show(), select() ,count(), groupBy()', 'Yes', 'deepu-04', 'https://github.com/deepu-04/capgemini-data-engineering-training', 'https://github.com/deepu-04/capgemini-data-engineering-training/tree/main/week0'),
('28-03-2026 12:55', '22pa1a0554@vishnu.edu.in', 'I learned basic PySpark methods like show(), select(), filter(), groupBy(), and count(). These helped me to display data, apply conditions, select columns, and perform aggregations. I also understood how PySpark DataFrames work similar to SQL tables.', 'Yes', 'deepikagundu2622', 'https://github.com/deepikagundu2622/capgemini-data-engineering-training.git', 'https://github.com/deepikagundu2622/capgemini-data-engineering-training/tree/main/phase1'),
('28-03-2026 14:55', '22pa1a1293@vishnu.edu.in', 'i learnt\n1.Viewing Data\n2.Selecting Columns\n3.Filtering Data\n', 'Yes', 'Manasa-Codes', 'https://github.com/Manasa-Codes/capgemini-data-engineering-training', 'https://github.com/Manasa-Codes/capgemini-data-engineering-training/tree/main/week0/phase1'),
('05-04-2026 17:53', '22pa1a4505@vishnu.edu.in', 'show(), select(), filter(), basic groupBy().', 'Yes', 'Johnpaul-225', 'https://github.com/Johnpaul-225/capgemini-data-engineering-training', 'https://github.com/Johnpaul-225/capgemini-data-engineering-training/tree/main/week0/phase1'),
('28-03-2026 15:28', '23pa5a4506@vishnu.edu.in', 'Filter(), group by(), count(), where(),show()', 'Yes', 'praveenapagadala', 'https://github.com/praveenapagadala/capgemini-databricks-data-engineering/', 'https://github.com/praveenapagadala/capgemini-databricks-data-engineering/tree/main/week0/phase1'),
('28-03-2026 18:16', '22pa1a1275@vishnu.edu.in', 'DataFrame Creation → createDataFrame()\nViewing Data → show()\nView structure of DataFrame → printSchema()\nSelection & Filtering → select(), filter() / where()\nAggregation → groupBy(), count()\nSorting → orderBy()\nCreate/modify column → withColumn()\nRemove column → drop()\nGet unique values → distinct()\nRename column → withColumnRenamed()\nColumn reference → col()\nAlias→ alias()\nSQL Table creation → createOrReplaceTempView()\nRun SQL queries → spark.sql()', 'Yes', 'Siddhardha2330', 'https://github.com/Siddhardha2330/capgemini-data-engineering-training', 'https://github.com/Siddhardha2330/capgemini-data-engineering-training/tree/main/week0/phase1'),
('05-04-2026 18:24', '22pa1a0596@vishnu.edu.in', 'Today I learned basic PySpark methods for working with DataFrames, including SparkSession.builder.appName() to set the application name and createDataFrame() to create data. I used show() to display the data, filter() to apply conditions, and select() to choose specific columns. I also used groupBy() with the count() function to perform aggregations, and applied alias() to rename the output column', 'Yes', 'Mamilla-Praveen', 'https://github.com/Mamilla-Praveen/Capgemini-data-engineering-training/tree/main/Week0', 'https://github.com/Mamilla-Praveen/Capgemini-data-engineering-training/tree/main/Week0/phase1'),
('28-03-2026 15:47', '22pa1a0551@vishnu.edu.in', 'At beginning PySpark looked confused but later i came to understand it clearly. I learnt .select(), .filter(), .groupBy() methods and conversion of SQL queries to PySpark. Yes i want to continue to explore PySpark through https://www.sparkplayground.com/tutorials/pyspark\nbecause it explained me from the basics step by step and it gave examples for every cocept.', 'Yes', 'jyothisreevinaya', 'https://github.com/jyothisreevinaya/capgemini-data-engineering-training.git', 'https://github.com/jyothisreevinaya/capgemini-data-engineering-training/tree/main/week0/phase1'),
('06-04-2026 16:58', '22pa1a12j3@vishnu.edu.in', 'load(),show(),display(),filter(),select(),count(),collect(), groupBy()', 'Yes', 'SriBhargav999', 'https://github.com/SriBhargav999/capgemini-data-engineering-training', 'https://github.com/SriBhargav999/capgemini-data-engineering-training/tree/a138690a2faef9ff45889ce648788bd37a030141/week_0/Phase_1'),
('28-03-2026 18:10', '22pa1a05c0@vishnu.edu.in', 'I have learned pyspark basics and some methods like show(), filter(), select(), group by() for queries and worked on some queries. ', 'Yes', 'bhavyasri9', 'https://github.com/bhavyasri9/capgemini-data-engineering-training', 'https://github.com/bhavyasri9/capgemini-data-engineering-training/tree/main/week0/phase1'),
('05-04-2026 17:59', '22pa1a12j4@vishnu.edu.in', 'show() filter() count() where() isin() like() rlike() isNull() select() col() alias() drop() are the methods i have learnt', 'Yes', 'Zakiya-Tahseen2004', 'https://github.com/Zakiya-Tahseen2004/capgemini-data-engineering-training.git', 'https://github.com/Zakiya-Tahseen2004/capgemini-data-engineering-training/tree/main/week0/phase1'),
('28-03-2026 19:44', '22pa1a05i5@vishnu.edu.in', 'show(),select(),filter(),where(),groupby(),sum(),avg(),count(),orderby(),join(),drop()', 'Yes', 'yvvswaraag', 'https://github.com/yvvswaraag/capgemini-data-engineering-training', 'https://github.com/yvvswaraag/capgemini-data-engineering-training/tree/main/week0/phase1'),
('28-03-2026 19:49', '22pa1a05d4@vishnu.edu.in', 'select(),groupby(),filter()', 'Yes', '22pa1a05d4', 'https://github.com/22pa1a05d4/capgemini-data-engineering-training/tree/main/Week0', 'https://github.com/22pa1a05d4/capgemini-data-engineering-training/tree/main/Week0/Phase1'),
('28-03-2026 20:06', 'keerthisrivalli18@gmail.com', 'I learnt methods like select(), filter(), groupBy(), show() and conditional operators', 'Yes', 'SagiKeerthisrivalli', 'https://github.com/SagiKeerthisrivalli/capgemini-data-engineering-training', 'https://github.com/SagiKeerthisrivalli/capgemini-data-engineering-training/tree/main/week0/phase1'),
('28-03-2026 20:26', '22pa1a5757@vishnu.edu.in', 'show(), printSchema(), describe(),read.csv(), read.json(), write.csv(), write.json(),select(),filter(), where(),groupBy(), count(), sum(), avg(), min(), max(),replace(),withColumn(),col()', 'Yes', 'MRsanjuedit', 'https://github.com/MRsanjuedit/capgemini-data-engineering-training', 'https://github.com/MRsanjuedit/capgemini-data-engineering-training/tree/main/Week-0/Phase-1'),
('28-03-2026 20:30', '22pa1a05f6@vishnu.edu.in', 'I have practiced PySpark methods like select(), filter(), withColumn(), groupBy(), orderBy(), and join() to perform data transformations and analysis.', 'Yes', 'shaikshajith', 'https://github.com/shaikshajith/Capgemini-data-engineering-training', 'https://github.com/shaikshajith/Capgemini-data-engineering-training/tree/main/Week0/Phase%201%20'),
('28-03-2026 20:30', '22pa1a05d7@vishnu.edu.in', 'I learned core PySpark DataFrame methods such as show(), select(), filter(), groupBy(), count(), and basic transformations while exploring data processing in Spark Playground.', 'Yes', 'Manasa0109', 'https://github.com/Manasa0109/Capgemini-data-engineering-training/tree/main', 'https://github.com/Manasa0109/Capgemini-data-engineering-training/tree/main/Week0/Phase1'),
('28-03-2026 22:08', '22pa1a12h3@vishnu.edu.in', 'DataFrame creation, selection, filtering, aggregation, joins, column operations', 'Yes', 'Rohith-lakshman', 'https://github.com/Rohith-lakshman/capgemini-data-engineering-training.git', 'https://github.com/Rohith-lakshman/capgemini-data-engineering-training/tree/master/week0/phase1'),
('28-03-2026 23:44', '22pa1a1209@vishnu.edu.in', '.show,filter,select,groupBy,alias,count', 'Yes', 'Vamsi1702', 'https://github.com/Vamsi1702/capgemini-data-engineering-training', 'https://github.com/Vamsi1702/capgemini-data-engineering-training/tree/main/week%200/Phase%201'),
('31-03-2026 20:43', '22pa1a1211@vishnu.edu.in', 'select, group by,alias,count,filter.', 'Yes', 'ChanduSaiAlladi', 'https://github.com/ChanduSaiAlladi/Capgemini-data-engineering-training', 'https://github.com/ChanduSaiAlladi/Capgemini-data-engineering-training/tree/main/week-0/phase-1'),
('29-03-2026 00:16', '22pa1a42b2@vishnu.edu.in', 'I learned some basic things in PySpark while working with data. I understood how to see the data, pick only the columns I need, and filter the data based on conditions.\nI also learned how to group the data and do simple counting. Along with that, I practiced changing column names, adding new columns, and removing unwanted ones.It helped me understand how to work with data in an easy and simple way using PySpark.', 'Yes', 'manaswini-vellanki', 'https://github.com/manaswini-vellanki/capgemini-data-engineering-training/', 'https://github.com/manaswini-vellanki/capgemini-data-engineering-training/tree/main/week0/phase1'),
('05-04-2026 18:38', '22pa1a5740@vishnu.edu.in', 'efilter(), where(),groupBy(), count(), sum(), avg(), min(), max(),replace(),withColumn(),col()', 'Yes', 'Nagaraju-40', 'https://github.com/Nagaraju-40/capgemini-data-engineering-training/tree/main/Week-0', 'https://github.com/Nagaraju-40/capgemini-data-engineering-training/tree/main/Week-0/Phase-1'),
('05-04-2026 17:52', '22pa1a4241@vishnu.edu.in', 'In PySpark, I learned basic DataFrame methods which are similar to SQL queries.\nThe show() method is used to display the data. The select() method is used to choose specific columns from the DataFrame. The filter() method helps to get rows based on conditions, like selecting customers from a particular city.\nI also learned groupBy() which is used to group data, and count() to count the number of records. These are useful for doing simple analysis like counting customers in each city.\nI understood that a DataFrame in PySpark works like a table in SQL, where we can perform operations such as selecting, filtering, and grouping data easily.\nOverall, these methods helped me understand how to work with data in PySpark in a simple and efficient way.\n', 'Yes', ' gonnabattulalikitha123', 'https://github.com/gonnabattulalikitha123/capgemini-data-engineering-training/tree/main/week0', 'https://github.com/gonnabattulalikitha123/capgemini-data-engineering-training/tree/main/week0/phase-1'),
('29-03-2026 11:41', '22pa1a12h4@vishnu.edu.in', 'select(),filter(),groupBy()', 'Yes', 'KavyaSreeTeegireddy', 'https://github.com/KavyaSreeTeegireddy/capgemini-data-engineering-training/tree/main/week0', 'https://github.com/KavyaSreeTeegireddy/capgemini-data-engineering-training/tree/main/week0/phase1'),
('29-03-2026 16:02', '22pa1a1283@vishnu.edu.in', 'selecting, viewing, filtering data', 'Yes', 'sowmya1415', 'https://github.com/sowmya1415/capgemini-data-engineering-training-/tree/main/week0', 'https://github.com/sowmya1415/capgemini-data-engineering-training-/tree/main/week0/phase1'),
('29-03-2026 16:06', '22pa1a45a1@vishnu.edu.in', 'Dataframe creation , Display data , Filter rows , selection of columns , aggregation of data and groupby ', 'Yes', 'ChaitanyaSannidhi', 'https://github.com/ChaitanyaSannidhi/Capgemini-data-engineering/tree/main/Week%200', 'https://github.com/ChaitanyaSannidhi/Capgemini-data-engineering/blob/main/Week%200/Phase%201/Readme.MD'),
('29-03-2026 17:27', '22pa1a1285@vishnu.edu.in', 'I learned several pyspark methods like \n.select()\n.show()\n.filter()\n.orderBy()\n.groupBy()', 'Yes', '22pa1a1285', 'https://github.com/22pa1a1285/capgemini-data-engineering-training/tree/main/Week0', 'https://github.com/22pa1a1285/capgemini-data-engineering-training/tree/main/Week0/Phase1'),
('05-04-2026 19:39', '22pa1a04a7@vishnu.edu.in', 'In PySpark, I learned methods like select(), filter(), groupBy(), agg(), count(), show(), join(), and withColumn().', 'Yes', 'Anusha195', 'https://github.com/Anusha195/capgemini-data-engineering-training', 'https://github.com/Anusha195/capgemini-data-engineering-training/tree/main/week0/phase0'),
('05-04-2026 18:43', '22pa1a5726@vishnu.edu.in', 'show(), filter(), select(), groupBy()', 'Yes', 'kattamuru-vaishnavi', 'https://github.com/kattamuru-vaishnavi/capgemini-data-engineering-training/tree/main/week0', 'https://github.com/kattamuru-vaishnavi/capgemini-data-engineering-training/tree/main/week0/phase1'),
('29-03-2026 20:35', '22pa1a0467@vishnu.edu.in', 'show(), select(), filter(), groupBy(), agg(), orderBy(), withColumn(), drop(), join(), distinct(), count()\n', 'Yes', 'NAMRATHA356', 'https://github.com/NAMRATHA356/capgemini-data-engineering-training', 'https://github.com/NAMRATHA356/capgemini-data-engineering-training/tree/main/week%200/phase%201'),
('29-03-2026 21:22', '22pa1a0475@vishnu.edu.in', 'PySpark provides methods like select(), filter(), groupBy(), show(), and count() to transform and process large datasets efficiently.', 'Yes', '22pa1a0475', 'https://github.com/22pa1a0475/capgemini-data-engineering-training', 'https://github.com/22pa1a0475/capgemini-data-engineering-training/tree/main/week%200/phase%201'),
('29-03-2026 21:23', 'velagaharshavardhan21@gmail.com', 'n my PySpark practice, I learned several important methods that helped me work with data effectively. I started with creating a SparkSession to initialize the environment, and then used createDataFrame() to convert raw data into structured format. To understand and verify the data, I used show(). I applied conditions using filter(), which is similar to SQL’s WHERE clause, and selected specific columns using select(), just like SQL SELECT. I also performed grouping operations using groupBy().count() to analyze data category-wise. Overall, these methods helped me understand how PySpark works through step-by-step transformations rather than writing a single query.', 'Yes', 'Harsha201105', 'https://github.com/Harsha201105/capgemini-data-engineering-training/tree/main', 'https://github.com/Harsha201105/capgemini-data-engineering-training/tree/main/week0/phase1'),
('29-03-2026 22:40', '22pa1a45a9@vishnu.edu.in', 'I learned various PySpark methods such as select(), filter(), groupBy(), agg(), join(), withColumn(), drop(), orderBy(), and show() for efficient data processing and analysis.', 'Yes', 'Bhagavathi-12', 'https://github.com/Bhagavathi-12/capgemini-data-engineering-training', 'https://github.com/Bhagavathi-12/capgemini-data-engineering-training/tree/main/week-0/phase-1'),
('29-03-2026 22:46', '22pa1a5754@vishnu.edu.in', 'Filtering, selection and basic queries,data handling ', 'Yes', 'Lucky356278992we6', 'https://github.com/Lucky356278992we6/databricks-week-0-foundation', 'https://github.com/Lucky356278992we6/databricks-week-0-foundation/new/main/phase1'),
('29-03-2026 22:48', '22pa1a04e0@vishnu.edu.in', 'I learnt PySpark methods such as select(), filter(), groupBy(), orderBy(), withColumn() and join() which are used to perform transformation on data.', 'Yes', 'kavyasamyuktha', 'https://github.com/kavyasamyuktha/Capgemini-Data-Engineering-Training/tree/main', 'https://github.com/kavyasamyuktha/Capgemini-Data-Engineering-Training/tree/main/Week0/Phase1'),
('29-03-2026 23:38', '22pa1a5719@vishnu.edu.in', 'show\nfilter\ngroupby\ncount\nselect\nwhy == in pyspark but = in sql', 'Yes', ' Nandinijagatha', 'https://github.com/Nandinijagatha/databricks-week0-foundation-', 'https://github.com/Nandinijagatha/databricks-week0-foundation-/tree/main/phase1'),
('30-03-2026 00:35', '22pa1a0405@vishnu.edu.in', 'I learned basic PySpark methods like show(), select(), filter(), and groupBy(), which are similar to SQL operations. These helped me understand how to process and analyze data using PySpark in a simple way.', 'Yes', 'CharanReddyAlavala', 'https://github.com/CharanReddyAlavala/capgemini-data-engineering-training', 'https://github.com/CharanReddyAlavala/capgemini-data-engineering-training/tree/main/week0/phase1'),
('30-03-2026 00:47', '22pa1a1203@vishnu.edu.in', 'I learned important PySpark methods like show(), select(), filter(), groupBy(), and agg(), which helped me work with data easily. I also explored more functions in Spark Playground to better understand data transformations and operations.\n', 'Yes', 'SiddhardhaAdey', 'https://github.com/SiddhardhaAdey/capgemini-data-engineering-training', 'https://github.com/SiddhardhaAdey/capgemini-data-engineering-training/tree/main/week0/phase1'),
('30-03-2026 01:25', '22pa1a4506@vishnu.edu.in', 'In PySpark I learned how to start with a SparkSession and work mainly with DataFrames by using methods like select and filter to transform data. I also practiced aggregation functions such as groupBy() and count(). Apart from DataFrames, I explored basic RDD operations like map() and reduce(). I understood how to read and write data in different formats like CSV and Parquet, and how to run SQL queries using temporary views.', 'Yes', 'https://github.com/alpzj', 'https://github.com/alpzj/capgemini-data-engineering-training', 'https://github.com/alpzj/capgemini-data-engineering-training/tree/main/Phase1'),
('05-04-2026 17:41', '22pa1a4580@vishnu.edu.in', 'I learned PySpark methods such as creating a Spark session, building DataFrames, and to view data, applying filters for querying, using  transformations, performing  aggregation operations.', 'Yes', 'HARSHA4580', 'https://github.com/HARSHA4580/Capgemini-data-engineering', 'https://github.com/HARSHA4580/Capgemini-data-engineering/tree/main/phase%201'),
('30-03-2026 10:44', '23pa5a1202@vishnu.edu.in', 'In PySpark, I learned basic methods like read.csv() for loading data, show() for viewing, select() and filter() for processing, withColumn() for transformations, groupBy() for aggregation, and join() for combining data. These methods help in efficiently handling and analyzing large datasets.', 'Yes', 'deepakbonthu', 'https://github.com/deepakbonthu/capgemini-data-engineering-training/tree/main', 'https://github.com/deepakbonthu/capgemini-data-engineering-training/tree/main/week0%2Fphase1'),
('05-04-2026 17:44', '22pa1a12f7@vishnu.edu.in', 'Filtering the data\nabout spark session\nselecting columns ', 'Yes', 'viveksadhucodes', 'https://github.com/viveksadhucodes/capgemini-data-engineering-training/tree/main', 'https://github.com/viveksadhucodes/capgemini-data-engineering-training/tree/main/Week0/Phase1'),
('30-03-2026 11:53', '22pa1a1240@vishnu.edu.in', 'This week i started with pyspark and sql basics. i tried to run pyspark in my local but so many errors came like java not found and pip is not recognized and also pyspark version was not compatible with python version so i waste lot of time on that only. then i used spark playground website and it was much easier.\nin sql i learned SELECT, WHERE and GROUP BY. in pyspark same thing is written differently like instead of WHERE we use .filter() and instead of SELECT we use .select() so it take some time to remember.\ni also learned .show() to print the dataframe and .groupBy() with .agg() for counting groupwise.\noverall phase 1 was good. now moving to phase 2 for joins and aggregations.', 'Yes', 'Amar-1240', 'https://github.com/Amar-1240/capgemini-data-engineering-training/tree/main/week0', 'https://github.com/Amar-1240/capgemini-data-engineering-training/tree/main/week0/phase1'),
('05-04-2026 11:24', '22pa1a5713@vishnu.edu.in', 'In Phase 1, I learned several PySpark methods such as show() to display data, select() to choose specific columns, filter() to apply conditions, groupBy() to group data, and count() to perform aggregations. These methods helped me understand how to perform basic data operations in PySpark.', 'Yes', 'Farhana1103', 'https://github.com/Farhana1103/Capgemini-data-engineering-training/tree/main/Week-0', 'https://github.com/Farhana1103/Capgemini-data-engineering-training/tree/main/Week-0/Phase-1'),
('30-03-2026 15:24', '22pa1a1246@vishnu.edu.in', 'Learned PySpark methods for data loading, transformation, and analysis such as read(), select(), filter(), withColumn(), groupBy(), agg(), and join().\nAlso used functions for handling missing data, window operations, SQL queries, and writing data like na.fill(), row_number(), spark.sql(), and write().', 'Yes', 'balabhargavi12', 'https://github.com/balabhargavi12/capgemini-data-engineering-training/tree/main', 'https://github.com/balabhargavi12/capgemini-data-engineering-training/tree/main/week0/phase1'),
('30-03-2026 17:05', '22pa1a1265@vishnu.edu.in', 'Learned PySpark methods for data loading, transformation, and analysis such as read(), select(), filter(), withColumn(), groupBy(), agg(), and join().\nAlso used functions for handling missing data, window operations, SQL queries, and writing data like na.fill(), row_number(), spark.sql(), and write().', 'Yes', 'GAYATHRI7171', 'https://github.com/GAYATHRI7171/Capgemini-data-engineering-training/tree/main', 'https://github.com/GAYATHRI7171/Capgemini-data-engineering-training/tree/main/Week0/Phase1'),
('30-03-2026 17:07', '22pa1a4582@vishnu.edu.in', 'Basic Filtering:using Filter and where Methods,filtering with isin() method,filtering with startswith()', 'Yes', 'Hanumanarra', 'https://github.com/Hanumanarra/data-engineering-training', 'https://github.com/Hanumanarra/data-engineering-training/tree/main/week0/phase1'),
('31-03-2026 10:47', '22pa1a4573@vishnu.edu.in', 'Basics of pyspark, Reading and writing files, filtering columns and data', 'Yes', 'YASHWANTH5566', 'https://github.com/YASHWANTH5566/capgemini-data-engineering-training', 'https://github.com/YASHWANTH5566/capgemini-data-engineering-training/tree/main/week0/phase0'),
('31-03-2026 13:09', '22pa1a5745@vishnu.edu.in', 'select(), filter(), where(), groupBy(), agg(), count(), sum(), avg(), join(), withColumn(), drop(), orderBy(), fillna(), dropna(), pivot().\n', 'Yes', 'https://github.com/Chandu777777', 'https://github.com/Chandu777777/databricks-week--foundation-', 'https://github.com/Chandu777777/databricks-week--foundation-/tree/main/phase1'),
('01-04-2026 12:55', '23pa5a0515@vishnu.edu.in', 'During Phase 1 of PySpark learning, I explored several important DataFrame methods used for data manipulation and analysis like show(), filter(), select(), groupBy(), count(), createDataFrame(), SparkSession.builder.appName().getOrCreate().', 'Yes', 'Meghanasri-mogili', 'https://github.com/Meghanasri-mogili/capgemini-data-engineering-training', 'https://github.com/Meghanasri-mogili/capgemini-data-engineering-training/tree/main/week0/phase1'),
('05-04-2026 20:34', '22pa1a4215@vishnu.edu.in', 'In the Spark playground, we learn the essential PySpark methods to work with data easily. We start by loading data from CSV or JSON files. To see what our data looks like, we use show() to display it, printSchema() to check its structure, and columns to list the column names. We can pick specific columns with select() and filter rows using filter() or where(). Adding new columns or changing existing ones is simple with withColumn(), and unnecessary columns can be removed with drop(). For summaries, we use groupBy() and count(), and to organize our data, we sort it with orderBy(). If we need to combine datasets, we use join(), and once everything looks good, we can save our results using write.csv().', 'Yes', '22pa1a4215-hue', 'https://github.com/22pa1a4215-hue/capgemini-data-engineering-training', 'https://github.com/22pa1a4215-hue/capgemini-data-engineering-training/tree/main/week0/phase1'),
('02-04-2026 22:34', 'varmagadiraju0318@gmail.com', 'I learned PySpark by executing basic SQL operations like CREATE, INSERT, UPDATE, and SELECT in the Spark Playground.\nI worked with tables by creating them, inserting data, modifying records, and retrieving results using SQL queries.', 'No', 'GadirajuSaiRamanjaneyaVarma1817', 'https://github.com/GadirajuSaiRamanjaneyaVarma1817/week_0.git', "https://github.com/GadirajuSaiRamanjaneyaVarma1817/week_0/tree/main/Varma''s/week_0/phase_1"),
('03-04-2026 09:59', '22pa1a45c3@vishnu.edu.in', 'select,filter,groupby,show', 'Yes', 'sravani05555', 'https://github.com/sravani05555/Data-engineering-training', 'https://drive.google.com/drive/folders/1buATrn599Qmdv62A_WqYxjyGsUO0sHCw?usp=drive_link'),
('03-04-2026 12:35', '22pa1a4244@vishnu.edu.in', 'show() – display the DataFrame  \nselect()– select required columns  \nfilter()– filter rows based on condition  \ngroupBy() – group data for aggregation  \ncount()– count records  \n', 'Yes', 'ganeshgudala123', 'https://github.com/ganeshgudala123/Capgemini_DataEngineering_Training/blob/main/README.md', 'https://github.com/ganeshgudala123/Capgemini_DataEngineering_Training/tree/main/DataEngineering-Training/Week0/phase%201'),
('03-04-2026 23:21', '22pa1a12g0@vishnu.edu.in', 'select(),groupby(),filter()', 'Yes', 'seedarapusantosh1', 'https://github.com/seedarapusantosh1/capgemini-data-engineering-training.git', '74fb134fb1f568f1c4088930fecff8b7f690b135/week0/phase1'),
('04-04-2026 13:36', '22pa1a42b4@vishnu.edu.in', 'While learning PySpark from the tutorial at Spark Playground PySpark Tutorial, several important DataFrame methods and operations are commonly practice', 'Yes', 'Kasumohan29', 'https://github.com/Kasumohan29/mohan-capgemini-data-training/tree/main/week0', 'https://github.com/Kasumohan29/mohan-capgemini-data-training/tree/10097a71d9fc74c220496fde5bb38e15aec2f4de/week0/phase1'),
('05-04-2026 18:39', '22pa1a4235@vishnu.edu.in', 'learned PySpark by executing basic SQL operations like CREATE, INSERT, UPDATE, and SELECT in the Spark Playground.\nI worked with tables by creating them, inserting data, modifying records, and retrieving results using SQL queries.', 'Yes', 'GadirajuSaiRamanjaneyaVarma1817', 'https://github.com/GadirajuSaiRamanjaneyaVarma1817/capgemini-data-engineering-training', 'https://github.com/GadirajuSaiRamanjaneyaVarma1817/capgemini-data-engineering-training/tree/main/week%200/phase%201'),
('05-04-2026 18:40', '22pa1a5740@vishnu.edu.in', 'select(),filter(), where(),groupBy(), count(), sum(), avg(), min(), max(),replace(),withColumn(),col()', 'Yes', 'Nagaraju-40', 'https://github.com/Nagaraju-40/capgemini-data-engineering-training/tree/main/Week-0', 'https://github.com/Nagaraju-40/capgemini-data-engineering-training/tree/main/Week-0/Phase-1');
-- Out:
-- ---------------------------------------------------------------------------
-- UnknownException                          Traceback (most recent call last)
-- File <command-6106795495826616>, line 1
-- ----> 1 get_ipython().run_cell_magic('sql', '', 'INSERT INTO student_submissions4\n(timestamp, email, pyspark_methods, completed_queries, github_username, repository_link, phase1_folder_link)\nVALUES\n(\'05-04-2026 18:44\', \'22pa1a42a9@vishnu.edu.in\', \'show,groupby,count,select,filter\', \'Yes\', \'Poorna-135\', \'https://github.com/Poorna-135/Capgemini-DataEngineering-training/tree/main\', \'https://github.com/Poorna-135/capgemini-data-engineering-training/tree/main/week%200/phase1\'),\n(\'05-04-2026 18:00\', \'22pa1a4279@vishnu.edu.in\', \'i learn how to setup the pyspark ,  creating sparksession, creating a dataframe, and apply some filters on the table like filter,count,show,groupby and select .\', \'Yes\', \'Nallamellisubhash\', \'https://github.com/Nallamellisubhash/capgemini-data-engineering-training\', \'https://github.com/Nallamellisubhash/capgemini-data-engineering-training/tree/main/Week0/phase1\'),\n(\'28-03-2026 22:02\', \'22pa1a12e7@vishnu.edu.in\', \'filter() , show(), select() ,count(), groupBy()\', \'Yes\', \'deepu-04\', \'https://github.com/deepu-04/capgemini-data-engineering-training\', \'https://github.com/deepu-04/capgemini-data-engineering-training/tree/main/week0\'),\n(\'28-03-2026 12:55\', \'22pa1a0554@vishnu.edu.in\', \'I learned basic PySpark methods like show(), select(), filter(), groupBy(), and count(). These helped me to display data, apply conditions, select columns, and perform aggregations. I also understood how PySpark DataFrames work similar to SQL tables.\', \'Yes\', \'deepikagundu2622\', \'https://github.com/deepikagundu2622/capgemini-data-engineering-training.git\', \'https://github.com/deepikagundu2622/capgemini-data-engineering-training/tree/main/phase1\'),\n(\'28-03-2026 14:55\', \'22pa1a1293@vishnu.edu.in\', \'i learnt\\n1.Viewing Data\\n2.Selecting Columns\\n3.Filtering Data\\n\', \'Yes\', \'Manasa-Codes\', \'https://github.com/Manasa-Codes/capgemini-data-engineering-training\', \'https://github.com/Manasa-Codes/capgemini-data-engineering-training/tree/main/week0/phase1\'),\n(\'05-04-2026 17:53\', \'22pa1a4505@vishnu.edu.in\', \'show(), select(), filter(), basic groupBy().\', \'Yes\', \'Johnpaul-225\', \'https://github.com/Johnpaul-225/capgemini-data-engineering-training\', \'https://github.com/Johnpaul-225/capgemini-data-engineering-training/tree/main/week0/phase1\'),\n(\'28-03-2026 15:28\', \'23pa5a4506@vishnu.edu.in\', \'Filter(), group by(), count(), where(),show()\', \'Yes\', \'praveenapagadala\', \'https://github.com/praveenapagadala/capgemini-databricks-data-engineering/\', \'https://github.com/praveenapagadala/capgemini-databricks-data-engineering/tree/main/week0/phase1\'),\n(\'28-03-2026 18:16\', \'22pa1a1275@vishnu.edu.in\', \'DataFrame Creation → createDataFrame()\\nViewing Data → show()\\nView structure of DataFrame → printSchema()\\nSelection & Filtering → select(), filter() / where()\\nAggregation → groupBy(), count()\\nSorting → orderBy()\\nCreate/modify column → withColumn()\\nRemove column → drop()\\nGet unique values → distinct()\\nRename column → withColumnRenamed()\\nColumn reference → col()\\nAlias→ alias()\\nSQL Table creation → createOrReplaceTempView()\\nRun SQL queries → spark.sql()\', \'Yes\', \'Siddhardha2330\', \'https://github.com/Siddhardha2330/capgemini-data-engineering-training\', \'https://github.com/Siddhardha2330/capgemini-data-engineering-training/tree/main/week0/phase1\'),\n(\'05-04-2026 18:24\', \'22pa1a0596@vishnu.edu.in\', \'Today I learned basic PySpark methods for working with DataFrames, including SparkSession.builder.appName() to set the application name and createDataFrame() to create data. I used show() to display the data, filter() to apply conditions, and select() to choose specific columns. I also used groupBy() with the count() function to perform aggregations, and applied alias() to rename the output column\', \'Yes\', \'Mamilla-Praveen\', \'https://github.com/Mamilla-Praveen/Capgemini-data-engineering-training/tree/main/Week0\', \ ...
--
-- File /databricks/python/lib/python3.12/site-packages/IPython/core/interactiveshell.py:2541, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
--    2539 with self.builtin_trap:
--    2540     args = (magic_arg_s, cell)
-- -> 2541     result = fn(*args, **kwargs)
--    2543 # The code below prevents the output from being displayed
--    2544 # when using magics with decorator @output_can_be_silenced
--    2545 # when the last Python token in the expression is a ';'.
--    2546 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
--
-- File /databricks/python_shell/lib/dbruntime/sql_magic/sql_magic.py:205, in SqlMagic.sql(self, line, cell)
--     198 except BaseException as e:
--     199     self.driver_activity_logger.logExecuteCommandEvent(
--     200         "SQL_MAGIC_PY4J_FAILED",
--     201         exceptionClassName=e.__class__.__name__,
--     202         sqlState=safe_call(e, "getSqlState"),
--     203         errorClass=safe_call(e, "getCondition"),
--     204     )
-- --> 205     raise e
--     207 self.driver_activity_logger.logExecuteCommandEvent("SQL_MAGIC_PY4J_SUCCEEDED")
--     208 return result
--
-- File /databricks/python_shell/lib/dbruntime/sql_magic/sql_magic.py:197, in SqlMagic.sql(self, line, cell)
--     195         query_text = sub_query.query()
--     196         sql_directive = self.entry_point.getSqlDirective(query_text)
-- --> 197         result = self._handle_sql_directive(sql_directive, i == number_of_sub_queries - 1)
--     198 except BaseException as e:
--     199     self.driver_activity_logger.logExecuteCommandEvent(
--     200         "SQL_MAGIC_PY4J_FAILED",
--     201         exceptionClassName=e.__class__.__name__,
--     202         sqlState=safe_call(e, "getSqlState"),
--     203         errorClass=safe_call(e, "getCondition"),
--     204     )
--
-- File /databricks/python_shell/lib/dbruntime/sql_magic/sql_magic.py:217, in SqlMagic._handle_sql_directive(self, sql_directive, is_last_query)
--     215     query = sql_directive.sql()
--     216     self._register_udf_if_needed(query)
-- --> 217     df = self._get_query_request_result(query)
--     218 elif directive_name in ("CreateView", "DropTable", "AlterTable", "CreateTable"):
--     219     self._get_query_request_result(sql_directive.sql())
--
-- File /databricks/python_shell/lib/dbruntime/sql_magic/sql_magic.py:161, in SqlMagic._get_query_request_result(self, query)
--     159 if len(widget_bindings := self._widget_cache.values) > 0:
--     160     self.driver_activity_logger.logExecuteCommandEvent("PARAM_SYNTAX_USAGE")
-- --> 161 df = self.spark.sql(query, widget_bindings)
--     162 return df
--
-- File /databricks/python/lib/python3.12/site-packages/pyspark/sql/connect/session.py:901, in SparkSession.sql(self, sqlQuery, args, **kwargs)
--     898         _views.append(SubqueryAlias(df._plan, name))
--     900 cmd = SQL(sqlQuery, _args, _named_args, _views)
-- --> 901 data, properties, ei = self.client.execute_command(cmd.command(self._client))
--     902 if "sql_command_result" in properties:
--     903     df = DataFrame(CachedRelation(properties["sql_command_result"]), self)
--
-- File /databricks/python/lib/python3.12/site-packages/pyspark/sql/connect/client/core.py:1538, in SparkConnectClient.execute_command(self, command, observations, extra_request_metadata)
--    1536     req.user_context.user_id = self._user_id
--    1537 self._set_command_in_plan(req.plan, command)
-- -> 1538 data, _, metrics, observed_metrics, properties = self._execute_and_fetch(
--    1539     req, observations or {}, extra_request_metadata
--    1540 )
--    1541 # Create a query execution object.
--    1542 ei = ExecutionInfo(metrics, observed_metrics)
--
-- File /databricks/python/lib/python3.12/site-packages/pyspark/sql/connect/client/core.py:2086, in SparkConnectClient._execute_and_fetch(self, req, observations, extra_request_metadata, self_destruct)
--    2083 properties: Dict[str, Any] = {}
--    2085 with Progress(handlers=self._progress_handlers, operation_id=req.operation_id) as progress:
-- -> 2086     for response in self._execute_and_fetch_as_iterator(
--    2087         req, observations, extra_request_metadata or [], progress=progress
--    2088     ):
--    2089         if isinstance(response, StructType):
--    2090             schema = response
--
-- File /databricks/python/lib/python3.12/site-packages/pyspark/sql/connect/client/core.py:2062, in SparkConnectClient._execute_and_fetch_as_iterator(self, req, observations, extra_request_metadata, progress)
--    2060     raise kb
--    2061 except Exception as error:
-- -> 2062     self._handle_error(error)
--
-- File /databricks/python/lib/python3.12/site-packages/pyspark/sql/connect/client/core.py:2380, in SparkConnectClient._handle_error(self, error)
--    2378     self.thread_local.inside_error_handling = True
--    2379     if isinstance(error, grpc.RpcError):
-- -> 2380         self._handle_rpc_error(error)
--    2381     raise error
--    2382 finally:
--
-- File /databricks/python/lib/python3.12/site-packages/pyspark/sql/connect/client/core.py:2458, in SparkConnectClient._handle_rpc_error(self, rpc_error)
--    2454             logger.debug(f"Received ErrorInfo: {info}")
--    2456             self._handle_rpc_error_with_error_info(info, status.message, status_code)  # EDGE
-- -> 2458             raise convert_exception(
--    2459                 info,
--    2460                 status.message,
--    2461                 self._fetch_enriched_error(info),
--    2462                 self._display_server_stack_trace(),
--    2463                 status_code,
--    2464             ) from None
--    2466     raise SparkConnectGrpcException(
--    2467         message=status.message,
--    2468         sql_state=ErrorCode.CLIENT_UNEXPECTED_MISSING_SQL_STATE,  # EDGE
--    2469         grpc_status_code=status_code,
--    2470     ) from None
--    2471 else:
--
-- UnknownException: (com.databricks.sql.transaction.tahoe.schema.DeltaInvariantViolationException) [DELTA_EXCEED_CHAR_VARCHAR_LIMIT] Value "DataFrame Creation → createDataFrame()
-- Viewing Data → show()
-- View structure of DataFrame → printSchema()
-- Selection & Filtering → select(), filter() / where()
-- Aggregation → groupBy(), count()
-- Sorting → orderBy()
-- Create/modify column → withColumn()
-- Remove column → drop()
-- Get unique values → distinct()
-- Rename column → withColumnRenamed()
-- Column reference → col()
-- Alias→ alias()
-- SQL Table creation → createOrReplaceTempView()
-- Run SQL queries → spark.sql()" exceeds char/varchar type length limitation. Failed check: ((pyspark_methods IS NULL) OR (length(pyspark_methods) <= 255)).
--
-- JVM stacktrace:
-- com.databricks.sql.transaction.tahoe.schema.DeltaInvariantViolationException
-- 	at com.databricks.sql.transaction.tahoe.schema.DeltaInvariantViolationException$.getCharVarcharLengthInvariantViolationException(InvariantViolationException.scala:71)
-- 	at com.databricks.photon.PhotonException$.getSparkException(PhotonException.scala:381)
-- 	at com.databricks.photon.PhotonWriteResultHandler.getResult(PhotonWriteStageExec.scala:151)
-- 	at com.databricks.photon.PhotonBasicEvaluatorFactory$PhotonBasicEvaluator$$anon$1.open(PhotonBasicEvaluatorFactory.scala:258)
-- 	at com.databricks.photon.PhotonBasicEvaluatorFactory$PhotonBasicEvaluator$$anon$1.hasNextImpl(PhotonBasicEvaluatorFactory.scala:263)
-- 	at com.databricks.photon.PhotonBasicEvaluatorFactory$PhotonBasicEvaluator$$anon$1.$anonfun$hasNext$1(PhotonBasicEvaluatorFactory.scala:283)
-- 	at scala.runtime.java8.JFunction0$mcZ$sp.apply(JFunction0$mcZ$sp.scala:17)
-- 	at com.databricks.photon.metrics.BillableTimeTaskMetrics.withPhotonBilling(BillableTimeTaskMetrics.scala:71)
-- 	at org.apache.spark.TaskContext.runFuncAsBillable(TaskContext.scala:273)
-- 	at com.databricks.photon.PhotonBasicEvaluatorFactory$PhotonBasicEvaluator$$anon$1.hasNext(PhotonBasicEvaluatorFactory.scala:283)
-- 	at com.databricks.photon.CloseableIterator$$anon$10.hasNext(CloseableIterator.scala:211)
-- 	at org.apache.spark.sql.execution.datasources.FileFormatWriter$.$anonfun$writeUsingPhoton$3(FileFormatWriter.scala:742)
-- 	at org.apache.spark.scheduler.ResultTask.$anonfun$runTask$2(ResultTask.scala:76)
-- 	at com.databricks.spark.util.ExecutorFrameProfiler$.record(ExecutorFrameProfiler.scala:110)
-- 	at org.apache.spark.scheduler.ResultTask.$anonfun$runTask$1(ResultTask.scala:76)
-- 	at com.databricks.spark.util.ExecutorFrameProfiler$.record(ExecutorFrameProfiler.scala:110)
-- 	at org.apache.spark.scheduler.ResultTask.runTask(ResultTask.scala:62)
-- 	at org.apache.spark.TaskContext.runTaskWithListeners(TaskContext.scala:233)
-- 	at org.apache.spark.scheduler.Task.doRunTask(Task.scala:197)
-- 	at org.apache.spark.scheduler.Task.$anonfun$run$4(Task.scala:160)
-- 	at com.databricks.unity.UCSEphemeralState$Handle.runWith(UCSEphemeralState.scala:51)
-- 	at com.databricks.unity.HandleImpl.runWith(UCSHandle.scala:104)
-- 	at com.databricks.unity.HandleImpl.$anonfun$runWithAndClose$1(UCSHandle.scala:109)
-- 	at scala.util.Using$.resource(Using.scala:296)
-- 	at com.databricks.unity.HandleImpl.runWithAndClose(UCSHandle.scala:108)
-- 	at org.apache.spark.scheduler.TaskExecutionUtils$.withUCHandleForTaskExecution(Task.scala:355)
-- 	at org.apache.spark.scheduler.Task.$anonfun$run$3(Task.scala:154)
-- 	at org.apache.spark.scheduler.TaskExecutionUtils$.withCredentialsForTaskExecution(Task.scala:333)
-- 	at org.apache.spark.scheduler.Task.$anonfun$run$1(Task.scala:113)
-- 	at com.databricks.spark.util.ExecutorFrameProfiler$.record(ExecutorFrameProfiler.scala:110)
-- 	at org.apache.spark.scheduler.Task.run(Task.scala:108)
-- 	at org.apache.spark.executor.Executor$TaskRunner.$anonfun$run$12(Executor.scala:1388)
-- 	at org.apache.spark.util.SparkErrorUtils.tryWithSafeFinally(SparkErrorUtils.scala:86)
-- 	at org.apache.spark.util.SparkErrorUtils.tryWithSafeFinally$(SparkErrorUtils.scala:83)
-- 	at org.apache.spark.util.Utils$.tryWithSafeFinally(Utils.scala:111)
-- 	at org.apache.spark.executor.Executor$TaskRunner.$anonfun$run$3(Executor.scala:1392)
-- 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.scala:18)
-- 	at com.databricks.spark.util.ExecutorFrameProfiler$.record(ExecutorFrameProfiler.scala:110)
-- 	at org.apache.spark.executor.Executor$TaskRunner.run(Executor.scala:1234)
-- 	at com.databricks.aether.RDDTask.run(RDDTask.scala:252)
-- 	at com.databricks.aether.worker.WorkerTaskAttemptThread.$anonfun$runInternal$1(AetherWorkerImpl.scala:362)
-- 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.scala:18)
-- 	at com.databricks.aether.AetherInt64Gauge.scopedAdd(AetherServiceMetricImpls.scala:129)
-- 	at com.databricks.aether.worker.WorkerTaskAttemptThread.runInternal(AetherWorkerImpl.scala:351)
-- 	at com.databricks.aether.worker.WorkerTaskAttemptThread.run(AetherWorkerImpl.scala:328)
-- 	at com.databricks.aether.FairBlockingQueue$SlotCountingRunnable.run(FairBlockingQueue.java:647)
-- 	at java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1136)
-- 	at java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:635)
-- 	at java.lang.Thread.run(Thread.java:840)
-- 	at org.apache.spark.scheduler.DAGScheduler.$anonfun$runJob$1(DAGScheduler.scala:1823)
-- 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.scala:18)
-- 	at com.databricks.spark.util.FrameProfiler$.$anonfun$record$1(FrameProfiler.scala:114)
-- 	at com.databricks.spark.util.FrameProfilerExporter$.maybeExportFrameProfiler(FrameProfilerExporter.scala:203)
-- 	at com.databricks.spark.util.FrameProfiler$.record(FrameProfiler.scala:105)
-- 	at org.apache.spark.scheduler.DAGScheduler.runJob(DAGScheduler.scala:1807)
-- 	at org.apache.spark.SparkContext.runJobInternal(SparkContext.scala:3299)
-- 	at org.apache.spark.SparkContext.runJob(SparkContext.scala:3280)
-- 	at org.apache.spark.sql.execution.datasources.FileFormatWriter$.$anonfun$writeUsingPhoton$2(FileFormatWriter.scala:739)
-- 	at org.apache.spark.sql.execution.datasources.FileFormatWriter$.ignoreMaxResultLimit(FileFormatWriter.scala:940)
-- 	at org.apache.spark.sql.execution.datasources.FileFormatWriter$.$anonfun$writeUsingPhoton$1(FileFormatWriter.scala:737)
-- 	at org.apache.spark.sql.catalyst.MetricKeyUtils$.measureMs(MetricKey.scala:2342)
-- 	at org.apache.spark.sql.execution.datasources.FileFormatWriter$.writeUsingPhoton(FileFormatWriter.scala:737)
-- 	at org.apache.spark.sql.execution.datasources.FileFormatWriter$.$anonfun$write$23(FileFormatWriter.scala:334)
-- 	at org.apache.spark.sql.execution.datasources.FileFormatWriter$.writeAndCommit(FileFormatWriter.scala:457)
-- 	at org.apache.spark.sql.execution.datasources.FileFormatWriter$.$anonfun$write$1(FileFormatWriter.scala:322)
-- 	at com.databricks.spark.util.FrameProfiler$.$anonfun$record$1(FrameProfiler.scala:114)
-- 	at com.databricks.spark.util.FrameProfilerExporter$.maybeExportFrameProfiler(FrameProfilerExporter.scala:203)
-- 	at com.databricks.spark.util.FrameProfiler$.record(FrameProfiler.scala:105)
-- 	at org.apache.spark.sql.execution.datasources.FileFormatWriter$.write(FileFormatWriter.scala:130)
-- 	at com.databricks.sql.transaction.tahoe.commands.WriteIntoDeltaCommand.run(WriteIntoDeltaCommand.scala:113)
-- 	at org.apache.spark.sql.execution.command.DataWritingCommandExec.$anonfun$sideEffectResult$5(commands.scala:140)
-- 	at org.apache.spark.sql.execution.SparkPlan.runCommandInAetherOrSpark(SparkPlan.scala:201)
-- 	at org.apache.spark.sql.execution.command.DataWritingCommandExec.$anonfun$sideEffectResult$4(commands.scala:140)
-- 	at com.databricks.spark.util.FrameProfiler$.$anonfun$record$1(FrameProfiler.scala:114)
-- 	at com.databricks.spark.util.FrameProfilerExporter$.maybeExportFrameProfiler(FrameProfilerExporter.scala:203)
-- 	at com.databricks.spark.util.FrameProfiler$.record(FrameProfiler.scala:105)
-- 	at org.apache.spark.sql.execution.command.DataWritingCommandExec.sideEffectResult$lzycompute(commands.scala:136)
-- 	at org.apache.spark.sql.execution.command.DataWritingCommandExec.sideEffectResult(commands.scala:135)
-- 	at org.apache.spark.sql.execution.command.DataWritingCommandExec.executeCollect(commands.scala:152)
-- 	at com.databricks.sql.transaction.tahoe.files.TransactionalWriteEdge.$anonfun$writeFilesAndGetQueryExecution$18(TransactionalWriteEdge.scala:759)
-- 	at org.apache.spark.sql.execution.SQLExecution$.$anonfun$withNewExecutionId0$18(SQLExecution.scala:706)
-- 	at com.databricks.sql.util.MemoryTrackerHelper.withMemoryTracking(MemoryTrackerHelper.scala:111)
-- 	at org.apache.spark.sql.execution.SQLExecution$.$anonfun$withNewExecutionId0$16(SQLExecution.scala:642)
-- 	at org.apache.spark.sql.execution.SQLExecution$.withSessionTagsApplied(SQLExecution.scala:1051)
-- 	at org.apache.spark.sql.execution.SQLExecution$.$anonfun$withNewExecutionId0$15(SQLExecution.scala:551)
-- 	at org.apache.spark.JobArtifactSet$.withActiveJobArtifactState(JobArtifactSet.scala:97)
-- 	at org.apache.spark.sql.artifact.ArtifactManager.$anonfun$withResources$1(ArtifactManager.scala:124)
-- 	at org.apache.spark.sql.artifact.ArtifactManager.withClassLoaderIfNeeded(ArtifactManager.scala:118)
-- 	at org.apache.spark.sql.artifact.ArtifactManager.withResources(ArtifactManager.scala:123)
-- 	at org.apache.spark.sql.execution.SQLExecution$.$anonfun$withNewExecutionId0$14(SQLExecution.scala:551)
-- 	at org.apache.spark.sql.execution.SQLExecution$.withSQLConfPropagated(SQLExecution.scala:1086)
-- 	at org.apache.spark.sql.execution.SQLExecution$.$anonfun$withNewExecutionId0$1(SQLExecution.scala:550)
-- 	at org.apache.spark.sql.SparkSession.withActive(SparkSession.scala:860)
-- 	at org.apache.spark.sql.execution.SQLExecution$.withNewExecutionId0(SQLExecution.scala:367)
-- 	at org.apache.spark.sql.execution.SQLExecution$.withNewExecutionId(SQLExecution.scala:1004)
-- 	at com.databricks.sql.transaction.tahoe.files.TransactionalWriteEdge.$anonfun$writeFilesAndGetQueryExecution$1(TransactionalWriteEdge.scala:753)
-- 	at com.databricks.sql.transaction.tahoe.metering.DeltaLogging.withOperationTypeTag(DeltaLogging.scala:811)
-- 	at com.databricks.sql.transaction.tahoe.metering.DeltaLogging.withOperationTypeTag$(DeltaLogging.scala:798)
-- 	at com.databricks.sql.transaction.tahoe.OptimisticTransaction.withOperationTypeTag(OptimisticTransaction.scala:230)
-- 	at com.databricks.sql.transaction.tahoe.metering.DeltaLogging.$anonfun$recordDeltaOperationInternal$2(DeltaLogging.scala:512)
-- 	at com.databricks.spark.util.FrameProfiler$.$anonfun$record$1(FrameProfiler.scala:114)
-- 	at com.databricks.spark.util.FrameProfilerExporter$.maybeExportFrameProfiler(FrameProfilerExporter.scala:203)
-- 	at com.databricks.spark.util.FrameProfiler$.record(FrameProfiler.scala:105)
-- 	at com.databricks.sql.transaction.tahoe.metering.DeltaLogging.recordFrameProfile(DeltaLogging.scala:904)
-- 	at com.databricks.sql.transaction.tahoe.metering.DeltaLogging.recordFrameProfile$(DeltaLogging.scala:902)
-- 	at com.databricks.sql.transaction.tahoe.OptimisticTransaction.recordFrameProfile(OptimisticTransaction.scala:230)
-- 	at com.databricks.sql.transaction.tahoe.metering.DeltaLogging.$anonfun$recordDeltaOperationInternal$1(DeltaLogging.scala:511)
-- 	at com.databricks.logging.UsageLogging.$anonfun$recordOperation$1(UsageLogging.scala:512)
-- 	at com.databricks.logging.UsageLogging.executeThunkAndCaptureResultTags$1(UsageLogging.scala:632)
-- 	at com.databricks.logging.UsageLogging.$anonfun$recordOperationWithResultTags$5(UsageLogging.scala:659)
-- 	at com.databricks.logging.AttributionContextTracing.$anonfun$withAttributionContext$1(AttributionContextTracing.scala:117)
-- 	at com.databricks.logging.AttributionContext$.$anonfun$withValue$1(AttributionContext.scala:348)
-- 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:59)
-- 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:344)
-- 	at com.databricks.logging.AttributionContextTracing.withAttributionContext(AttributionContextTracing.scala:115)
-- 	at com.databricks.logging.AttributionContextTracing.withAttributionContext$(AttributionContextTracing.scala:112)
-- 	at com.databricks.spark.util.PublicDBLogging.withAttributionContext(DatabricksSparkUsageLogger.scala:29)
-- 	at com.databricks.logging.AttributionContextTracing.withAttributionTags(AttributionContextTracing.scala:172)
-- 	at com.databricks.logging.AttributionContextTracing.withAttributionTags$(AttributionContextTracing.scala:153)
-- 	at com.databricks.spark.util.PublicDBLogging.withAttributionTags(DatabricksSparkUsageLogger.scala:29)
-- 	at com.databricks.logging.UsageLogging.recordOperationWithResultTags(UsageLogging.scala:627)
-- 	at com.databricks.logging.UsageLogging.recordOperationWithResultTags$(UsageLogging.scala:521)
-- 	at com.databricks.spark.util.PublicDBLogging.recordOperationWithResultTags(DatabricksSparkUsageLogger.scala:29)
-- 	at com.databricks.logging.UsageLogging.recordOperation(UsageLogging.scala:513)
-- 	at com.databricks.logging.UsageLogging.recordOperation$(UsageLogging.scala:477)
-- 	at com.databricks.spark.util.PublicDBLogging.recordOperation(DatabricksSparkUsageLogger.scala:29)
-- 	at com.databricks.spark.util.PublicDBLogging.recordOperation0(DatabricksSparkUsageLogger.scala:104)
-- 	at com.databricks.spark.util.DatabricksSparkUsageLogger.recordOperation(DatabricksSparkUsageLogger.scala:193)
-- 	at com.databricks.spark.util.UsageLogger.recordOperation(UsageLogger.scala:78)
-- 	at com.databricks.spark.util.UsageLogger.recordOperation$(UsageLogger.scala:65)
-- 	at com.databricks.spark.util.DatabricksSparkUsageLogger.recordOperation(DatabricksSparkUsageLogger.scala:152)
-- 	at com.databricks.spark.util.UsageLogging.recordOperation(UsageLogger.scala:537)
-- 	at com.databricks.spark.util.UsageLogging.recordOperation$(UsageLogger.scala:516)
-- 	at com.databricks.sql.transaction.tahoe.OptimisticTransaction.recordOperation(OptimisticTransaction.scala:230)
-- 	at com.databricks.sql.transaction.tahoe.metering.DeltaLogging.recordDeltaOperationInternal(DeltaLogging.scala:510)
-- 	at com.databricks.sql.transaction.tahoe.metering.DeltaLogging.recordDeltaOperation(DeltaLogging.scala:500)
-- 	at com.databricks.sql.transaction.tahoe.metering.DeltaLogging.recordDeltaOperation$(DeltaLogging.scala:489)
-- 	at com.databricks.sql.transaction.tahoe.OptimisticTransaction.recordDeltaOperation(OptimisticTransaction.scala:230)
-- 	at com.databricks.sql.transaction.tahoe.files.TransactionalWriteEdge.$anonfun$recordWriteFilesOperation$1(TransactionalWriteEdge.scala:335)
-- 	at com.databricks.sql.acl.CheckPermissions$.$anonfun$trusted$2(CheckPermissions.scala:2684)
-- 	at com.databricks.sql.util.ThreadLocalTagger.withTag(QueryTagger.scala:63)
-- 	at com.databricks.sql.util.ThreadLocalTagger.withTag$(QueryTagger.scala:60)
-- 	at com.databricks.sql.util.QueryTagger$.withTag(QueryTagger.scala:237)
-- 	at com.databricks.sql.acl.CheckPermissions$.trusted(CheckPermissions.scala:2684)
-- 	at com.databricks.sql.transaction.tahoe.files.TransactionalWriteEdge.recordWriteFilesOperation(TransactionalWriteEdge.scala:334)
-- 	at com.databricks.sql.transaction.tahoe.files.TransactionalWriteEdge.writeFilesAndGetQueryExecution(TransactionalWriteEdge.scala:393)
-- 	at com.databricks.sql.transaction.tahoe.files.TransactionalWriteEdge.writeFilesAndGetQueryExecution$(TransactionalWriteEdge.scala:383)
-- 	at com.databricks.sql.transaction.tahoe.OptimisticTransaction.writeFilesAndGetQueryExecution(OptimisticTransaction.scala:230)
-- 	at com.databricks.sql.transaction.tahoe.files.TransactionalWriteEdge.writeFilesAndGetExecutedPlan(TransactionalWriteEdge.scala:967)
-- 	at com.databricks.sql.transaction.tahoe.files.TransactionalWriteEdge.writeFilesAndGetExecutedPlan$(TransactionalWriteEdge.scala:947)
-- 	at com.databricks.sql.transaction.tahoe.OptimisticTransaction.writeFilesAndGetExecutedPlan(OptimisticTransaction.scala:230)
-- 	at com.databricks.sql.transaction.tahoe.commands.ClusteredWriter.writeFilesWithoutClustering(ClusteredWriter.scala:1175)
-- 	at com.databricks.sql.transaction.tahoe.commands.ClusteredWriter.runInternal(ClusteredWriter.scala:312)
-- 	at com.databricks.sql.transaction.tahoe.commands.ClusteredWriter.runAndReturnMaterializationPlans(ClusteredWriter.scala:258)
-- 	at com.databricks.sql.transaction.tahoe.commands.WriteIntoDeltaEdge.writeFilesAndGetMaterializationPlans(WriteIntoDeltaEdge.scala:914)
-- 	at com.databricks.sql.transaction.tahoe.commands.WriteIntoDeltaEdge.writeAndReturnCommitDataAndMaterializationPlans(WriteIntoDeltaEdge.scala:828)
-- 	at com.databricks.sql.transaction.tahoe.commands.WriteIntoDeltaEdge.writeAndReturnCommitData(WriteIntoDeltaEdge.scala:323)
-- 	at com.databricks.sql.transaction.tahoe.commands.WriteIntoDeltaEdge.$anonfun$run$5(WriteIntoDeltaEdge.scala:209)
-- 	at com.databricks.sql.transaction.tahoe.DeltaLog.withNewTransaction(DeltaLog.scala:342)
-- 	at com.databricks.sql.transaction.tahoe.commands.WriteIntoDeltaEdge.$anonfun$run$1(WriteIntoDeltaEdge.scala:196)
-- 	at com.databricks.sql.acl.CheckPermissions$.$anonfun$trusted$2(CheckPermissions.scala:2684)
-- 	at com.databricks.sql.util.ThreadLocalTagger.withTag(QueryTagger.scala:63)
-- 	at com.databricks.sql.util.ThreadLocalTagger.withTag$(QueryTagger.scala:60)
-- 	at com.databricks.sql.util.QueryTagger$.withTag(QueryTagger.scala:237)
-- 	at com.databricks.sql.acl.CheckPermissions$.trusted(CheckPermissions.scala:2684)
-- 	at com.databricks.sql.transaction.tahoe.commands.WriteIntoDeltaEdge.run(WriteIntoDeltaEdge.scala:183)
-- 	at com.databricks.sql.transaction.tahoe.catalog.WriteIntoDeltaBuilder$$anon$3$$anon$4.insert(DeltaTableV2.scala:1219)
-- 	at org.apache.spark.sql.execution.datasources.v2.SupportsV1Write.writeWithV1(V1FallbackWriters.scala:136)
-- 	at org.apache.spark.sql.execution.datasources.v2.SupportsV1Write.writeWithV1$(V1FallbackWriters.scala:117)
-- 	at org.apache.spark.sql.execution.datasources.v2.AppendDataExecV1.writeWithV1(V1FallbackWriters.scala:35)
-- 	at org.apache.spark.sql.execution.datasources.v2.V1FallbackWriters.run(V1FallbackWriters.scala:83)
-- 	at org.apache.spark.sql.execution.datasources.v2.V1FallbackWriters.run$(V1FallbackWriters.scala:81)
-- 	at org.apache.spark.sql.execution.datasources.v2.AppendDataExecV1.run(V1FallbackWriters.scala:35)
-- 	at org.apache.spark.sql.execution.datasources.v2.V2CommandExec.$anonfun$result$2(V2CommandExec.scala:48)
-- 	at org.apache.spark.sql.execution.SparkPlan.runCommandInAetherOrSpark(SparkPlan.scala:201)
-- 	at org.apache.spark.sql.execution.datasources.v2.V2CommandExec.$anonfun$result$1(V2CommandExec.scala:48)
-- 	at com.databricks.spark.util.FrameProfiler$.$anonfun$record$1(FrameProfiler.scala:114)
-- 	at com.databricks.spark.util.FrameProfilerExporter$.maybeExportFrameProfiler(FrameProfilerExporter.scala:203)
-- 	at com.databricks.spark.util.FrameProfiler$.record(FrameProfiler.scala:105)
-- 	at org.apache.spark.sql.execution.datasources.v2.V2CommandExec.result$lzycompute(V2CommandExec.scala:47)
-- 	at org.apache.spark.sql.execution.datasources.v2.V2CommandExec.result(V2CommandExec.scala:45)
-- 	at org.apache.spark.sql.execution.datasources.v2.V2CommandExec.executeCollect(V2CommandExec.scala:56)
-- 	at org.apache.spark.sql.execution.QueryExecution.$anonfun$eagerlyExecuteCommands$6(QueryExecution.scala:737)
-- 	at com.databricks.util.LexicalThreadLocal$Handle.runWith(LexicalThreadLocal.scala:63)
-- 	at org.apache.spark.sql.execution.QueryExecution.$anonfun$eagerlyExecuteCommands$5(QueryExecution.scala:737)
-- 	at com.databricks.util.LexicalThreadLocal$Handle.runWith(LexicalThreadLocal.scala:63)
-- 	at org.apache.spark.sql.execution.QueryExecution.$anonfun$eagerlyExecuteCommands$4(QueryExecution.scala:736)
-- 	at org.apache.spark.sql.catalyst.QueryPlanningTracker$.withTracker(QueryPlanningTracker.scala:266)
-- 	at org.apache.spark.sql.execution.QueryExecution.$anonfun$eagerlyExecuteCommands$3(QueryExecution.scala:734)
-- 	at org.apache.spark.sql.execution.SQLExecution$.$anonfun$withNewExecutionId0$18(SQLExecution.scala:706)
-- 	at com.databricks.sql.util.MemoryTrackerHelper.withMemoryTracking(MemoryTrackerHelper.scala:111)
-- 	at org.apache.spark.sql.execution.SQLExecution$.$anonfun$withNewExecutionId0$16(SQLExecution.scala:642)
-- 	at org.apache.spark.sql.execution.SQLExecution$.withSessionTagsApplied(SQLExecution.scala:1051)
-- 	at org.apache.spark.sql.execution.SQLExecution$.$anonfun$withNewExecutionId0$15(SQLExecution.scala:551)
-- 	at org.apache.spark.JobArtifactSet$.withActiveJobArtifactState(JobArtifactSet.scala:97)
-- 	at org.apache.spark.sql.artifact.ArtifactManager.$anonfun$withResources$1(ArtifactManager.scala:124)
-- 	at org.apache.spark.sql.artifact.ArtifactManager.withClassLoaderIfNeeded(ArtifactManager.scala:118)
-- 	at org.apache.spark.sql.artifact.ArtifactManager.withResources(ArtifactManager.scala:123)
-- 	at org.apache.spark.sql.execution.SQLExecution$.$anonfun$withNewExecutionId0$14(SQLExecution.scala:551)
-- 	at org.apache.spark.sql.execution.SQLExecution$.withSQLConfPropagated(SQLExecution.scala:1086)
-- 	at org.apache.spark.sql.execution.SQLExecution$.$anonfun$withNewExecutionId0$1(SQLExecution.scala:550)
-- 	at org.apache.spark.sql.SparkSession.withActive(SparkSession.scala:860)
-- 	at org.apache.spark.sql.execution.SQLExecution$.withNewExecutionId0(SQLExecution.scala:367)
-- 	at org.apache.spark.sql.execution.SQLExecution$.withNewExecutionId(SQLExecution.scala:1004)
-- 	at org.apache.spark.sql.execution.QueryExecution.$anonfun$eagerlyExecuteCommands$2(QueryExecution.scala:712)
-- 	at org.apache.spark.sql.execution.QueryExecution$.withInternalError(QueryExecution.scala:1766)
-- 	at org.apache.spark.sql.execution.QueryExecution.$anonfun$eagerlyExecuteCommands$1(QueryExecution.scala:712)
-- 	at org.apache.spark.sql.execution.QueryExecution.withMVTagsIfNecessary(QueryExecution.scala:653)
-- 	at org.apache.spark.sql.execution.QueryExecution.org$apache$spark$sql$execution$QueryExecution$$eagerlyExecute$1(QueryExecution.scala:710)
-- 	at org.apache.spark.sql.execution.QueryExecution$$anonfun$$nestedInanonfun$eagerlyExecuteCommands$10$1.applyOrElse(QueryExecution.scala:849)
-- 	at org.apache.spark.sql.execution.QueryExecution$$anonfun$$nestedInanonfun$eagerlyExecuteCommands$10$1.applyOrElse(QueryExecution.scala:841)
-- 	at org.apache.spark.sql.catalyst.trees.TreeNode.$anonfun$transformDownWithPruning$1(TreeNode.scala:569)
-- 	at org.apache.spark.sql.catalyst.trees.CurrentOrigin$.withOrigin(origin.scala:142)
-- 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformDownWithPruning(TreeNode.scala:569)
-- 	at org.apache.spark.sql.catalyst.plans.logical.LogicalPlan.org$apache$spark$sql$catalyst$plans$logical$AnalysisHelper$$super$transformDownWithPruning(LogicalPlan.scala:47)
-- 	at org.apache.spark.sql.catalyst.plans.logical.AnalysisHelper.transformDownWithPruning(AnalysisHelper.scala:361)
-- 	at org.apache.spark.sql.catalyst.plans.logical.AnalysisHelper.transformDownWithPruning$(AnalysisHelper.scala:357)
-- 	at org.apache.spark.sql.catalyst.plans.logical.LogicalPlan.transformDownWithPruning(LogicalPlan.scala:47)
-- 	at org.apache.spark.sql.catalyst.plans.logical.LogicalPlan.transformDownWithPruning(LogicalPlan.scala:47)
-- 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformDown(TreeNode.scala:545)
-- 	at org.apache.spark.sql.execution.QueryExecution.$anonfun$eagerlyExecuteCommands$10(QueryExecution.scala:841)
-- 	at org.apache.spark.sql.catalyst.plans.logical.AnalysisHelper$.allowInvokingTransformsInAnalyzer(AnalysisHelper.scala:418)
-- 	at org.apache.spark.sql.execution.QueryExecution.eagerlyExecuteCommands(QueryExecution.scala:841)
-- 	at org.apache.spark.sql.execution.QueryExecution.$anonfun$lazyCommandExecuted$1(QueryExecution.scala:609)
-- 	at scala.util.Try$.apply(Try.scala:217)
-- 	at org.apache.spark.util.Utils$.doTryWithCallerStacktrace(Utils.scala:1693)
-- 	at org.apache.spark.util.Utils$.getTryWithCallerStacktrace(Utils.scala:1754)
-- 	at org.apache.spark.util.LazyTry.get(LazyTry.scala:75)
-- 	at org.apache.spark.sql.execution.QueryExecution.commandExecuted(QueryExecution.scala:614)
-- 	at org.apache.spark.sql.classic.Dataset.<init>(Dataset.scala:431)
-- 	at org.apache.spark.sql.classic.Dataset$.$anonfun$ofRows$3(Dataset.scala:154)
-- 	at org.apache.spark.sql.SparkSession.withActive(SparkSession.scala:860)
-- 	at org.apache.spark.sql.classic.SparkSession.$anonfun$withActiveAndFrameProfiler$1(SparkSession.scala:1279)
-- 	at com.databricks.spark.util.FrameProfiler$.$anonfun$record$1(FrameProfiler.scala:114)
-- 	at com.databricks.spark.util.FrameProfilerExporter$.maybeExportFrameProfiler(FrameProfilerExporter.scala:203)
-- 	at com.databricks.spark.util.FrameProfiler$.record(FrameProfiler.scala:105)
-- 	at org.apache.spark.sql.classic.SparkSession.withActiveAndFrameProfiler(SparkSession.scala:1279)
-- 	at org.apache.spark.sql.classic.Dataset$.ofRows(Dataset.scala:145)
-- 	at org.apache.spark.sql.classic.SparkSession.$anonfun$sql$5(SparkSession.scala:971)
-- 	at org.apache.spark.sql.SparkSession.withActive(SparkSession.scala:860)
-- 	at org.apache.spark.sql.classic.SparkSession.sql(SparkSession.scala:931)
-- 	at org.apache.spark.sql.connect.planner.SparkConnectPlanner.executeSQL(SparkConnectPlanner.scala:3980)
-- 	at org.apache.spark.sql.connect.planner.SparkConnectPlanner.handleSqlCommand(SparkConnectPlanner.scala:3808)
-- 	at org.apache.spark.sql.connect.planner.SparkConnectPlanner.process(SparkConnectPlanner.scala:3593)
-- 	at org.apache.spark.sql.connect.execution.ExecuteThreadRunner.handleCommand(ExecuteThreadRunner.scala:404)
-- 	at org.apache.spark.sql.connect.execution.ExecuteThreadRunner.$anonfun$executeInternal$1(ExecuteThreadRunner.scala:282)
-- 	at org.apache.spark.sql.connect.execution.ExecuteThreadRunner.$anonfun$executeInternal$1$adapted(ExecuteThreadRunner.scala:239)
-- 	at org.apache.spark.sql.connect.service.SessionHolder.$anonfun$withSession$2(SessionHolder.scala:647)
-- 	at org.apache.spark.sql.SparkSession.withActive(SparkSession.scala:860)
-- 	at org.apache.spark.sql.connect.service.SessionHolder.$anonfun$withSession$1(SessionHolder.scala:647)
-- 	at org.apache.spark.JobArtifactSet$.withActiveJobArtifactState(JobArtifactSet.scala:97)
-- 	at org.apache.spark.sql.artifact.ArtifactManager.$anonfun$withResources$1(ArtifactManager.scala:124)
-- 	at org.apache.spark.sql.artifact.ArtifactManager.withClassLoaderIfNeeded(ArtifactManager.scala:118)
-- 	at org.apache.spark.sql.artifact.ArtifactManager.withResources(ArtifactManager.scala:123)
-- 	at org.apache.spark.sql.connect.service.SessionHolder.withSession(SessionHolder.scala:646)
-- 	at org.apache.spark.sql.connect.execution.ExecuteThreadRunner.executeInternal(ExecuteThreadRunner.scala:239)
-- 	at org.apache.spark.sql.connect.execution.ExecuteThreadRunner.$anonfun$execute$1(ExecuteThreadRunner.scala:143)
-- 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.scala:18)
-- 	at com.databricks.spark.connect.service.UtilizationMetrics.recordActiveQueries(UtilizationMetrics.scala:43)
-- 	at com.databricks.spark.connect.service.UtilizationMetrics.recordActiveQueries$(UtilizationMetrics.scala:40)
-- 	at org.apache.spark.sql.connect.execution.ExecuteThreadRunner.recordActiveQueries(ExecuteThreadRunner.scala:55)
-- 	at org.apache.spark.sql.connect.execution.ExecuteThreadRunner.org$apache$spark$sql$connect$execution$ExecuteThreadRunner$$execute(ExecuteThreadRunner.scala:141)
-- 	at org.apache.spark.sql.connect.execution.ExecuteThreadRunner$ExecutionThread.$anonfun$run$3(ExecuteThreadRunner.scala:609)
-- 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.scala:18)
-- 	at com.databricks.spark.util.DBRTracing$.withSpanFromParent(DBRTracing.scala:70)
-- 	at org.apache.spark.sql.connect.execution.ExecuteThreadRunner$ExecutionThread.$anonfun$run$2(ExecuteThreadRunner.scala:609)
-- 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.scala:18)
-- 	at com.databricks.unity.UCSEphemeralState$Handle.runWith(UCSEphemeralState.scala:51)
-- 	at com.databricks.unity.HandleImpl.runWith(UCSHandle.scala:104)
-- 	at com.databricks.unity.HandleImpl.$anonfun$runWithAndClose$1(UCSHandle.scala:109)
-- 	at scala.util.Using$.resource(Using.scala:296)
-- 	at com.databricks.unity.HandleImpl.runWithAndClose(UCSHandle.scala:108)
-- 	at org.apache.spark.sql.connect.execution.ExecuteThreadRunner$ExecutionThread.run(ExecuteThreadRunner.scala:608)
